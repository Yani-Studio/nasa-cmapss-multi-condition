# %% [markdown]
# 파일 별 데이터 분포 분석

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# 1. 경로 및 데이터 로드
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]

df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)

def plot_engine_sensors(df, engine_id, dataset_name):
    """지정한 엔진 번호의 모든 센서 변화를 시각화하는 함수"""
    engine_data = df[df["engine_id"] == engine_id]
    
    if engine_data.empty:
        print(f"해당 엔진 번호({engine_id})가 {dataset_name} 데이터에 없습니다.")
        return

    # 센서 21개를 3x7 배열로 시각화
    fig, axes = plt.subplots(3, 7, figsize=(20, 10))
    fig.suptitle(f"Sensor Analysis for Engine ID: {engine_id} ({dataset_name})", fontsize=16)
    
    for i, ax in enumerate(axes.flat):
        sensor_name = f"s{i+1}"
        ax.plot(engine_data["cycle"], engine_data[sensor_name], color='teal')
        ax.set_title(sensor_name, fontsize=10)
        ax.tick_params(axis='x', labelsize=8)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# --- 사용 예시 ---
# Train 데이터의 1번 엔진 시각화
plot_engine_sensors(df_train, engine_id=1, dataset_name="Train")

# Test 데이터의 1번 엔진 시각화
plot_engine_sensors(df_test, engine_id=1, dataset_name="Test")

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import os

# 1. 데이터 로드 및 경로 설정
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]

df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)

# 2. 정규화 대상 컬럼 지정 (setting1~3, s1~s21)
# cycle 컬럼은 엔진 수명을 나타내므로 정규화 대상에서 제외하거나 별도 관리합니다.
cols_to_normalize = [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]

# 3. 정규화 실행
scaler = MinMaxScaler()

# Train 데이터 정규화
df_train_norm = df_train.copy()
df_train_norm[cols_to_normalize] = scaler.fit_transform(df_train[cols_to_normalize])

# Test 데이터 정규화 (Train의 scaler를 그대로 사용해야 함)
df_test_norm = df_test.copy()
df_test_norm[cols_to_normalize] = scaler.transform(df_test[cols_to_normalize])

# 4. 결과 확인
print("=== 정규화 후 데이터 상위 5개 (일부 컬럼) ===")
print(df_train_norm[["engine_id", "cycle", "s2", "s3", "s4"]].head())

# 5. 시각화: 정규화 전 vs 후 비교 (1번 엔진의 s2 센서)
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(df_train[df_train['engine_id'] == 1]['s2'], color='red')
plt.title("Before Normalization (s2)")

plt.subplot(1, 2, 2)
plt.plot(df_train_norm[df_train_norm['engine_id'] == 1]['s2'], color='blue')
plt.title("After Normalization (s2)")
plt.show()
# Out:
# === 정규화 후 데이터 상위 5개 (일부 컬럼) ===
#    engine_id  cycle        s2        s3        s4
# 0          1      1  0.181576  0.311201  0.273095
# 1          1      2  0.131847  0.296600  0.245535
# 2          1      3  0.016332  0.035297  0.056997
# 3          1      4  0.128269  0.298795  0.246979
# 4          1      5  0.014130  0.037871  0.058152

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# 1. 경로 및 설정
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
setting_cols = [f"setting{i}" for i in range(1, 4)]
sensor_cols = [f"s{i}" for i in range(1, 22)]
features = setting_cols + sensor_cols

# 2. 데이터 로드
df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=["engine_id", "cycle"] + features)
df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=["engine_id", "cycle"] + features)
df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), sep=r"\s+", header=None, names=["RUL"])

# 3. 정규화 (Min-Max)
scaler = MinMaxScaler()
df_train[features] = scaler.fit_transform(df_train[features])
df_test[features] = scaler.transform(df_test[features])

# 4. 시각화 함수: 각 데이터셋의 모든 컬럼 분포(Histogram)를 출력
def plot_distributions(df, title):
    fig, axes = plt.subplots(4, 6, figsize=(20, 12))
    fig.suptitle(f"Distribution Analysis: {title}", fontsize=16, fontweight='bold')
    
    for i, col in enumerate(features):
        ax = axes.flat[i]
        sns.histplot(df[col], kde=True, ax=ax, color='skyblue')
        ax.set_title(col, fontsize=10)
        ax.set_xlabel("")
        ax.set_ylabel("")
    
    # 남는 칸 숨기기
    for j in range(len(features), len(axes.flat)):
        axes.flat[j].axis('off')
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# 5. 시각화 실행
plot_distributions(df_train, "Train Data (Normalized)")
plot_distributions(df_test, "Test Data (Normalized)")

# 6. RUL 분포 시각화 (RUL은 정규화 대상이 아님)
plt.figure(figsize=(6, 4))
sns.histplot(df_rul["RUL"], kde=True, color='salmon')
plt.title("RUL Distribution")
plt.show()

# 7. 데이터 갯수 확인 테이블
summary_table = pd.DataFrame({
    "구분": ["Train", "Test", "RUL"],
    "총 데이터 개수(Rows)": [len(df_train), len(df_test), len(df_rul)],
    "고유 엔진 개수": [df_train["engine_id"].nunique(), df_test["engine_id"].nunique(), len(df_rul)]
})
print("=== 데이터 요약 테이블 ===")
print(summary_table.to_string(index=False))
# Out:
# === 데이터 요약 테이블 ===
#    구분  총 데이터 개수(Rows)  고유 엔진 개수
# Train           53759       260
#  Test           33991       259
#   RUL             259       259

# %% [markdown]
# 왜 삭제하는가?
#
# 데이터 전처리 단계에서 이 과정은 '차원의 저주'를 방지하기 위함입니다. 위 이미지와 같은 데이터 분포 분석(Feature Distribution Analysis)을 통해 변동성이 없는 컬럼을 제거하는 이유는 다음과 같습니다.
#
# 신호 대 잡음비(SNR) 향상: 모델이 실제 중요한 센서(엔진의 열화 상태를 잘 보여주는 센서)에 집중하게 합니다.
#
# 학습 효율성: 불필요한 연산을 줄여 학습 속도를 높입니다.
#
# 일반화 성능: 노이즈(상수값)를 학습하여 과적합되는 것을 막아줍니다.

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, mean_absolute_error, r2_score
from pykalman import KalmanFilter

# --- 1. 설정 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
epochs = 1000
es_patience = 300 
lr_patience = 20

columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
# 요청하신 폐급 데이터 피처로 수정 완료
cols_to_drop = ['setting3', 's13', 's19']

# --- 2. 전처리 함수 정의 ---
def load_train_data():
    print("📢 1. Train 데이터 로딩 및 전처리 중...")
    df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_train.drop(columns=cols_to_drop, inplace=True)
    
    # Train RUL 계산
    df_max = df_train.groupby('engine_id')['cycle'].max().reset_index()
    df_train = df_train.merge(df_max.rename(columns={'cycle': 'max_cycle'}), on='engine_id')
    df_train['RUL'] = df_train['max_cycle'] - df_train['cycle']
    
    features = [c for c in df_train.columns if c not in ['engine_id', 'cycle', 'max_cycle', 'RUL']]
    
    # Scaler 학습 및 적용
    scaler = MinMaxScaler()
    df_train[features] = scaler.fit_transform(df_train[features])
    
    # 칼만 필터 적용 (Train)
    print("   - Train 데이터 칼만 필터링 적용 중...")
    for engine_id in df_train['engine_id'].unique():
        idx = df_train[df_train['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_train.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_train.loc[idx, features].values)
        df_train.loc[idx, features] = state_means
        
    return df_train, features, scaler

def load_test_data(features, scaler):
    print("📢 2. 진짜 Test 및 RUL 데이터 로딩 중...")
    df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_test.drop(columns=cols_to_drop, inplace=True)
    
    # Data Leakage 방지: Train Scaler로 transform만 수행
    df_test[features] = scaler.transform(df_test[features])
    
    # 칼만 필터 적용 (Test)
    print("   - Test 데이터 칼만 필터링 적용 중...")
    for engine_id in df_test['engine_id'].unique():
        idx = df_test[df_test['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_test.loc[idx, features].values)
        df_test.loc[idx, features] = state_means
        
    # RUL 정답지 로드
    df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
    df_rul['engine_id'] = df_rul.index + 1
    
    X_test_real, y_test_real = [], []
    
    # 각 테스트 엔진의 마지막 시점 기준 과거 sequence_length 만큼 시퀀스 추출
    for id in df_test['engine_id'].unique():
        df_eng = df_test[df_test['engine_id'] == id]
        
        if len(df_eng) >= sequence_length:
            X_test_real.append(df_eng[features].values[-sequence_length:])
            real_rul_val = df_rul[df_rul['engine_id'] == id]['true_rul'].values[0]
            y_test_real.append(real_rul_val)
            
    return np.array(X_test_real), np.array(y_test_real)

# --- 3. 모델 정의 ---
class Attention(layers.Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dense = layers.Dense(1, activation='tanh')
    def call(self, inputs):
        score = self.dense(inputs)
        weights = tf.nn.softmax(score, axis=1)
        return tf.reduce_sum(inputs * weights, axis=1)

def build_model(input_shape):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv1D(filters=64, kernel_size=3, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Bidirectional(layers.LSTM(100, return_sequences=True))(x)
    x = layers.Bidirectional(layers.LSTM(100, return_sequences=True))(x)
    x = Attention()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1)(x)
    model = models.Model(inputs, outputs)
    
    optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=0.004)
    model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=1.0))
    return model

# --- 4. 데이터 세트 빌드 ---
df_train, features, scaler = load_train_data()

X_all, y_all = [], []
for id in df_train['engine_id'].unique():
    df_eng = df_train[df_train['engine_id'] == id]
    for i in range(len(df_eng) - sequence_length + 1):
        X_all.append(df_eng[features].values[i:i+sequence_length])
        y_all.append(df_eng['RUL'].values[i+sequence_length-1])
X_all, y_all = np.array(X_all), np.array(y_all)

# Train 내부 Validation 분할
split_idx = int(len(X_all) * 0.8)
X_train, X_val = X_all[:split_idx], X_all[split_idx:]
y_train, y_val = y_all[:split_idx], y_all[split_idx:]

# 진짜 평가용 테스트 및 정답 세트 로드
X_test_real, y_test_real = load_test_data(features, scaler)

# --- 5. 모델 학습 ---
model = build_model((sequence_length, len(features)))

checkpoint = callbacks.ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

callbacks_list = [
    callbacks.EarlyStopping(monitor='val_loss', patience=es_patience, restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=lr_patience, min_lr=0.000001, verbose=1),
    checkpoint
]

history = model.fit(
    X_train, y_train, 
    epochs=epochs, 
    batch_size=128, 
    validation_data=(X_val, y_val),
    callbacks=callbacks_list,
    verbose=1
)

# 최적 모델 복원
model = models.load_model('best_model.keras', custom_objects={'Attention': Attention})

# --- 6. 진짜 테스트 데이터 기반 최종 성능 평가 ---
y_pred = model.predict(X_test_real).flatten()

# 회귀 지표 계산
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred))
mae = mean_absolute_error(y_test_real, y_pred)
r2 = r2_score(y_test_real, y_pred)
non_zero_mask = y_test_real > 0
mape = np.mean(np.abs((y_test_real[non_zero_mask] - y_pred[non_zero_mask]) / y_test_real[non_zero_mask])) * 100

print("\n================ [PERFORMANCE METRICS] ================")
print(f"RMSE : {rmse:.2f} cycles")
print(f"MAE  : {mae:.2f} cycles")
print(f"R2   : {r2:.4f}")
print(f"MAPE : {mape:.2f} %")

# 분류 지표 (고장 기준: 30 cycle 이하)
threshold = 30
y_true_cls = (y_test_real < threshold).astype(int)
y_pred_cls = (y_pred < threshold).astype(int)
cls_report = classification_report(y_true_cls, y_pred_cls, target_names=['Normal', 'Failure'])
cm = confusion_matrix(y_true_cls, y_pred_cls)

print("\n=========== [FAILURE PREDICTION ANALYSIS] ===========")
print(f"Failure Threshold: < {threshold} cycles")
print("Classification Report:")
print(cls_report)

print("Confusion Matrix Layout:")
print(f"True_Negative(Correct_Normal)   : {cm[0,0]}")
print(f"False_Positive(False_Alarm)     : {cm[0,1]}")
print(f"False_Negative(Missed_Failure)  : {cm[1,0]}")
print(f"True_Positive(Detected_Failure) : {cm[1,1]}")

# 시각화
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Training Loss')
plt.legend()

plt.subplot(1, 2, 2)
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', xticklabels=['Normal', 'Failure'], yticklabels=['Normal', 'Failure'])
plt.title('Confusion Matrix (Real Test)')
plt.show()
# Out:
# 📢 1. Train 데이터 로딩 및 전처리 중...
#    - Train 데이터 칼만 필터링 적용 중...
# 📢 2. 진짜 Test 및 RUL 데이터 로딩 중...
#    - Test 데이터 칼만 필터링 적용 중...
# Epoch 1/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 42.9030
# Epoch 1: val_loss improved from None to 36.53762, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 35s 186ms/step - loss: 38.5734 - val_loss: 36.5376 - learning_rate: 0.0010
# Epoch 2/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 33.3730
# Epoch 2: val_loss did not improve from 36.53762
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 34s 195ms/step - loss: 28.7448 - val_loss: 63.0318 - learning_rate: 0.0010
# Epoch 3/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 20.3445
# Epoch 3: val_loss improved from 36.53762 to 25.78694, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 35s 198ms/step - loss: 18.9455 - val_loss: 25.7869 - learning_rate: 0.0010
# Epoch 4/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 14.5908
# Epoch 4: val_loss improved from 25.78694 to 16.28285, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 13.8556 - val_loss: 16.2829 - learning_rate: 0.0010
# Epoch 5/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 11.9218
# Epoch 5: val_loss improved from 16.28285 to 14.10001, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 11.2833 - val_loss: 14.1000 - learning_rate: 0.0010
# Epoch 6/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 9.8704
# Epoch 6: val_loss improved from 14.10001 to 13.95537, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 9.4018 - val_loss: 13.9554 - learning_rate: 0.0010
# Epoch 7/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 8.5279
# Epoch 7: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 8.2210 - val_loss: 17.2838 - learning_rate: 0.0010
# Epoch 8/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 7.8730
# Epoch 8: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 7.2658 - val_loss: 15.4791 - learning_rate: 0.0010
# Epoch 9/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 6.9442
# Epoch 9: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 6.7253 - val_loss: 22.2057 - learning_rate: 0.0010
# Epoch 10/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 6.4852
# Epoch 10: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 6.3152 - val_loss: 14.5020 - learning_rate: 0.0010
# Epoch 11/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 6.9155
# Epoch 11: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 6.3564 - val_loss: 13.9933 - learning_rate: 0.0010
# Epoch 12/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 6.1100
# Epoch 12: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 5.8862 - val_loss: 17.1671 - learning_rate: 0.0010
# Epoch 13/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 5.6669
# Epoch 13: val_loss did not improve from 13.95537
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 5.6390 - val_loss: 15.3090 - learning_rate: 0.0010
# Epoch 14/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 6.0462
# Epoch 14: val_loss improved from 13.95537 to 13.74200, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 5.7131 - val_loss: 13.7420 - learning_rate: 0.0010
# Epoch 15/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 5.5432
# Epoch 15: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 5.3907 - val_loss: 14.9881 - learning_rate: 0.0010
# Epoch 16/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - loss: 5.3307
# Epoch 16: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 225ms/step - loss: 5.4183 - val_loss: 14.3120 - learning_rate: 0.0010
# Epoch 17/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 5.4376
# Epoch 17: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 5.3239 - val_loss: 15.2113 - learning_rate: 0.0010
# Epoch 18/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 5.3156
# Epoch 18: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 5.2475 - val_loss: 14.3697 - learning_rate: 0.0010
# Epoch 19/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 5.3953
# Epoch 19: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 5.2756 - val_loss: 17.6341 - learning_rate: 0.0010
# Epoch 20/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 5.1566
# Epoch 20: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 5.1483 - val_loss: 17.4971 - learning_rate: 0.0010
# Epoch 21/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 5.1468
# Epoch 21: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 5.1164 - val_loss: 17.1349 - learning_rate: 0.0010
# Epoch 22/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 5.3592
# Epoch 22: val_loss did not improve from 13.74200
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 5.2046 - val_loss: 13.8034 - learning_rate: 0.0010
# Epoch 23/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 5.1436
# Epoch 23: val_loss improved from 13.74200 to 13.61778, saving model to best_model.keras
#
# Epoch 23: finished saving model to best_model.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 5.0525 - val_loss: 13.6178 - learning_rate: 0.0010
# Epoch 24/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 5.0821
# Epoch 24: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 5.0549 - val_loss: 16.3982 - learning_rate: 0.0010
# Epoch 25/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 5.1382
# Epoch 25: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 5.0602 - val_loss: 15.4628 - learning_rate: 0.0010
# Epoch 26/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.8946
# Epoch 26: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.9534 - val_loss: 14.7237 - learning_rate: 0.0010
# Epoch 27/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.8791
# Epoch 27: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.8644 - val_loss: 15.1648 - learning_rate: 0.0010
# Epoch 28/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.8677
# Epoch 28: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.8665 - val_loss: 14.7279 - learning_rate: 0.0010
# Epoch 29/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.8719
# Epoch 29: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.8435 - val_loss: 14.4837 - learning_rate: 0.0010
# Epoch 30/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.8475
# Epoch 30: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.8766 - val_loss: 17.7264 - learning_rate: 0.0010
# Epoch 31/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 4.8794
# Epoch 31: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.8333 - val_loss: 15.9085 - learning_rate: 0.0010
# Epoch 32/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.7862
# Epoch 32: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.7260 - val_loss: 16.3501 - learning_rate: 0.0010
# Epoch 33/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.7949
# Epoch 33: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 4.8000 - val_loss: 15.2289 - learning_rate: 0.0010
# Epoch 34/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.9264
# Epoch 34: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 5.0321 - val_loss: 18.1775 - learning_rate: 0.0010
# Epoch 35/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.7046
# Epoch 35: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.7289 - val_loss: 16.7080 - learning_rate: 0.0010
# Epoch 36/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.6852
# Epoch 36: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.6844 - val_loss: 17.0323 - learning_rate: 0.0010
# Epoch 37/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.7376
# Epoch 37: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.7194 - val_loss: 16.2810 - learning_rate: 0.0010
# Epoch 38/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.7647
# Epoch 38: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.6781 - val_loss: 15.9778 - learning_rate: 0.0010
# Epoch 39/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.7569
# Epoch 39: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.7577 - val_loss: 15.5323 - learning_rate: 0.0010
# Epoch 40/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 5.1396
# Epoch 40: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.8712 - val_loss: 17.2719 - learning_rate: 0.0010
# Epoch 41/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.8179
# Epoch 41: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.7105 - val_loss: 17.4786 - learning_rate: 0.0010
# Epoch 42/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 4.7273
# Epoch 42: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.7181 - val_loss: 15.8221 - learning_rate: 0.0010
# Epoch 43/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.8068
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 43: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.7161 - val_loss: 16.2428 - learning_rate: 0.0010
# Epoch 44/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 4.5449
# Epoch 44: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.4450 - val_loss: 15.9518 - learning_rate: 3.0000e-04
# Epoch 45/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.3303
# Epoch 45: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.3619 - val_loss: 17.0848 - learning_rate: 3.0000e-04
# Epoch 46/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.3493
# Epoch 46: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.3380 - val_loss: 16.8795 - learning_rate: 3.0000e-04
# Epoch 47/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.2981
# Epoch 47: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.2950 - val_loss: 16.3408 - learning_rate: 3.0000e-04
# Epoch 48/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.3486
# Epoch 48: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 4.3172 - val_loss: 16.2413 - learning_rate: 3.0000e-04
# Epoch 49/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 4.3150
# Epoch 49: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 39s 223ms/step - loss: 4.3594 - val_loss: 15.6127 - learning_rate: 3.0000e-04
# Epoch 50/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 4.2938
# Epoch 50: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.3250 - val_loss: 15.9619 - learning_rate: 3.0000e-04
# Epoch 51/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.3793
# Epoch 51: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.3485 - val_loss: 16.7054 - learning_rate: 3.0000e-04
# Epoch 52/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 4.3181
# Epoch 52: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 39s 224ms/step - loss: 4.3238 - val_loss: 17.5287 - learning_rate: 3.0000e-04
# Epoch 53/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.4299
# Epoch 53: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 4.3551 - val_loss: 16.9168 - learning_rate: 3.0000e-04
# Epoch 54/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.3882
# Epoch 54: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.3818 - val_loss: 15.7366 - learning_rate: 3.0000e-04
# Epoch 55/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.3299
# Epoch 55: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.3259 - val_loss: 17.9814 - learning_rate: 3.0000e-04
# Epoch 56/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.3946
# Epoch 56: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.3649 - val_loss: 16.3986 - learning_rate: 3.0000e-04
# Epoch 57/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2732
# Epoch 57: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.2753 - val_loss: 17.5569 - learning_rate: 3.0000e-04
# Epoch 58/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.2836
# Epoch 58: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.3238 - val_loss: 16.3119 - learning_rate: 3.0000e-04
# Epoch 59/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.3337
# Epoch 59: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.3352 - val_loss: 18.0094 - learning_rate: 3.0000e-04
# Epoch 60/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.3294
# Epoch 60: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.3659 - val_loss: 17.1230 - learning_rate: 3.0000e-04
# Epoch 61/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.5476
# Epoch 61: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.4054 - val_loss: 16.4408 - learning_rate: 3.0000e-04
# Epoch 62/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 4.3631
# Epoch 62: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.3073 - val_loss: 16.5049 - learning_rate: 3.0000e-04
# Epoch 63/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.3126
# Epoch 63: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 63: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.2798 - val_loss: 15.3295 - learning_rate: 3.0000e-04
# Epoch 64/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.3332
# Epoch 64: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.2961 - val_loss: 16.0517 - learning_rate: 9.0000e-05
# Epoch 65/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.2709
# Epoch 65: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.2494 - val_loss: 16.5414 - learning_rate: 9.0000e-05
# Epoch 66/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.2916
# Epoch 66: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.2307 - val_loss: 16.1804 - learning_rate: 9.0000e-05
# Epoch 67/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.2872
# Epoch 67: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.2274 - val_loss: 16.4273 - learning_rate: 9.0000e-05
# Epoch 68/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 4.2191
# Epoch 68: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.2467 - val_loss: 15.8359 - learning_rate: 9.0000e-05
# Epoch 69/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1691
# Epoch 69: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.2293 - val_loss: 17.0499 - learning_rate: 9.0000e-05
# Epoch 70/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.2425
# Epoch 70: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.2457 - val_loss: 16.4472 - learning_rate: 9.0000e-05
# Epoch 71/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2381
# Epoch 71: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.2482 - val_loss: 16.2980 - learning_rate: 9.0000e-05
# Epoch 72/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1798
# Epoch 72: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.2178 - val_loss: 15.4868 - learning_rate: 9.0000e-05
# Epoch 73/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2424
# Epoch 73: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.2523 - val_loss: 16.0352 - learning_rate: 9.0000e-05
# Epoch 74/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.2203
# Epoch 74: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1841 - val_loss: 15.7892 - learning_rate: 9.0000e-05
# Epoch 75/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.2927
# Epoch 75: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.2320 - val_loss: 16.6701 - learning_rate: 9.0000e-05
# Epoch 76/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 4.2477
# Epoch 76: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.2434 - val_loss: 16.4370 - learning_rate: 9.0000e-05
# Epoch 77/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1588
# Epoch 77: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1810 - val_loss: 15.9419 - learning_rate: 9.0000e-05
# Epoch 78/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.2349
# Epoch 78: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.2318 - val_loss: 16.6304 - learning_rate: 9.0000e-05
# Epoch 79/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.3095
# Epoch 79: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.2408 - val_loss: 16.1324 - learning_rate: 9.0000e-05
# Epoch 80/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - loss: 4.2170
# Epoch 80: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 48s 271ms/step - loss: 4.1966 - val_loss: 17.0655 - learning_rate: 9.0000e-05
# Epoch 81/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 4.2115
# Epoch 81: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 248ms/step - loss: 4.1784 - val_loss: 16.1743 - learning_rate: 9.0000e-05
# Epoch 82/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1906
# Epoch 82: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.2077 - val_loss: 16.2055 - learning_rate: 9.0000e-05
# Epoch 83/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.2154
# Epoch 83: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 83: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.2331 - val_loss: 15.8703 - learning_rate: 9.0000e-05
# Epoch 84/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.2448
# Epoch 84: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.2052 - val_loss: 16.3264 - learning_rate: 2.7000e-05
# Epoch 85/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2852
# Epoch 85: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.2359 - val_loss: 16.5011 - learning_rate: 2.7000e-05
# Epoch 86/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.2460
# Epoch 86: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.1847 - val_loss: 16.0451 - learning_rate: 2.7000e-05
# Epoch 87/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.1673
# Epoch 87: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1711 - val_loss: 16.0374 - learning_rate: 2.7000e-05
# Epoch 88/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1862
# Epoch 88: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1779 - val_loss: 16.3032 - learning_rate: 2.7000e-05
# Epoch 89/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.2067
# Epoch 89: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1623 - val_loss: 16.2279 - learning_rate: 2.7000e-05
# Epoch 90/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.2338
# Epoch 90: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1838 - val_loss: 16.4544 - learning_rate: 2.7000e-05
# Epoch 91/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1675
# Epoch 91: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1717 - val_loss: 16.3149 - learning_rate: 2.7000e-05
# Epoch 92/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.2002
# Epoch 92: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.2191 - val_loss: 16.3540 - learning_rate: 2.7000e-05
# Epoch 93/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1639
# Epoch 93: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1985 - val_loss: 16.8030 - learning_rate: 2.7000e-05
# Epoch 94/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.2241
# Epoch 94: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.2197 - val_loss: 16.4076 - learning_rate: 2.7000e-05
# Epoch 95/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2261
# Epoch 95: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.2568 - val_loss: 16.2502 - learning_rate: 2.7000e-05
# Epoch 96/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1432
# Epoch 96: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1630 - val_loss: 16.3399 - learning_rate: 2.7000e-05
# Epoch 97/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1756
# Epoch 97: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 236ms/step - loss: 4.1962 - val_loss: 16.3397 - learning_rate: 2.7000e-05
# Epoch 98/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1937
# Epoch 98: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1708 - val_loss: 16.3254 - learning_rate: 2.7000e-05
# Epoch 99/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1641
# Epoch 99: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1730 - val_loss: 16.2357 - learning_rate: 2.7000e-05
# Epoch 100/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1767
# Epoch 100: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.2002 - val_loss: 16.0917 - learning_rate: 2.7000e-05
# Epoch 101/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.2317
# Epoch 101: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.2032 - val_loss: 16.3741 - learning_rate: 2.7000e-05
# Epoch 102/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1786
# Epoch 102: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.1664 - val_loss: 16.4204 - learning_rate: 2.7000e-05
# Epoch 103/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.2331
# Epoch 103: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 103: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.2266 - val_loss: 16.3179 - learning_rate: 2.7000e-05
# Epoch 104/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2297
# Epoch 104: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1971 - val_loss: 16.4473 - learning_rate: 8.1000e-06
# Epoch 105/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.0622
# Epoch 105: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1291 - val_loss: 16.3117 - learning_rate: 8.1000e-06
# Epoch 106/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1547
# Epoch 106: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.1439 - val_loss: 16.3665 - learning_rate: 8.1000e-06
# Epoch 107/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1844
# Epoch 107: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1757 - val_loss: 16.3898 - learning_rate: 8.1000e-06
# Epoch 108/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1319
# Epoch 108: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.1736 - val_loss: 16.2798 - learning_rate: 8.1000e-06
# Epoch 109/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1554
# Epoch 109: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1475 - val_loss: 16.2711 - learning_rate: 8.1000e-06
# Epoch 110/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1640
# Epoch 110: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1433 - val_loss: 16.3182 - learning_rate: 8.1000e-06
# Epoch 111/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.1834
# Epoch 111: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.2061 - val_loss: 16.2663 - learning_rate: 8.1000e-06
# Epoch 112/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.2025
# Epoch 112: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1461 - val_loss: 16.2343 - learning_rate: 8.1000e-06
# Epoch 113/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1239
# Epoch 113: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1427 - val_loss: 16.3201 - learning_rate: 8.1000e-06
# Epoch 114/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1643
# Epoch 114: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1644 - val_loss: 16.3688 - learning_rate: 8.1000e-06
# Epoch 115/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.2321
# Epoch 115: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.2126 - val_loss: 16.4878 - learning_rate: 8.1000e-06
# Epoch 116/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.2485
# Epoch 116: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1581 - val_loss: 16.3498 - learning_rate: 8.1000e-06
# Epoch 117/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1716
# Epoch 117: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1431 - val_loss: 16.3402 - learning_rate: 8.1000e-06
# Epoch 118/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 4.2082
# Epoch 118: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.1725 - val_loss: 16.4462 - learning_rate: 8.1000e-06
# Epoch 119/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1065
# Epoch 119: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1635 - val_loss: 16.3856 - learning_rate: 8.1000e-06
# Epoch 120/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1385
# Epoch 120: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1667 - val_loss: 16.3506 - learning_rate: 8.1000e-06
# Epoch 121/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2244
# Epoch 121: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1942 - val_loss: 16.3781 - learning_rate: 8.1000e-06
# Epoch 122/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1062
# Epoch 122: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1346 - val_loss: 16.5049 - learning_rate: 8.1000e-06
# Epoch 123/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1712
# Epoch 123: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 123: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1136 - val_loss: 16.3284 - learning_rate: 8.1000e-06
# Epoch 124/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.0975
# Epoch 124: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.1462 - val_loss: 16.3420 - learning_rate: 2.4300e-06
# Epoch 125/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1474
# Epoch 125: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1683 - val_loss: 16.3587 - learning_rate: 2.4300e-06
# Epoch 126/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1097
# Epoch 126: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1247 - val_loss: 16.3786 - learning_rate: 2.4300e-06
# Epoch 127/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1501
# Epoch 127: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1288 - val_loss: 16.3831 - learning_rate: 2.4300e-06
# Epoch 128/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.0942
# Epoch 128: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1622 - val_loss: 16.3451 - learning_rate: 2.4300e-06
# Epoch 129/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1973
# Epoch 129: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1649 - val_loss: 16.3098 - learning_rate: 2.4300e-06
# Epoch 130/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1482
# Epoch 130: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1795 - val_loss: 16.3536 - learning_rate: 2.4300e-06
# Epoch 131/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1091
# Epoch 131: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1006 - val_loss: 16.3756 - learning_rate: 2.4300e-06
# Epoch 132/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.2362
# Epoch 132: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.2099 - val_loss: 16.3754 - learning_rate: 2.4300e-06
# Epoch 133/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.1962
# Epoch 133: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1761 - val_loss: 16.3599 - learning_rate: 2.4300e-06
# Epoch 134/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.0873
# Epoch 134: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1471 - val_loss: 16.3296 - learning_rate: 2.4300e-06
# Epoch 135/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.0605
# Epoch 135: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1447 - val_loss: 16.3634 - learning_rate: 2.4300e-06
# Epoch 136/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 4.1267
# Epoch 136: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.0928 - val_loss: 16.3219 - learning_rate: 2.4300e-06
# Epoch 137/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1507
# Epoch 137: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1472 - val_loss: 16.3368 - learning_rate: 2.4300e-06
# Epoch 138/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.2041
# Epoch 138: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1754 - val_loss: 16.3768 - learning_rate: 2.4300e-06
# Epoch 139/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 4.2066
# Epoch 139: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 250ms/step - loss: 4.1815 - val_loss: 16.3564 - learning_rate: 2.4300e-06
# Epoch 140/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1568
# Epoch 140: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1396 - val_loss: 16.3680 - learning_rate: 2.4300e-06
# Epoch 141/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 4.1494
# Epoch 141: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 45s 257ms/step - loss: 4.1664 - val_loss: 16.3850 - learning_rate: 2.4300e-06
# Epoch 142/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.1779
# Epoch 142: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 247ms/step - loss: 4.1974 - val_loss: 16.3472 - learning_rate: 2.4300e-06
# Epoch 143/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.1981
# Epoch 143: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 143: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.1455 - val_loss: 16.3880 - learning_rate: 2.4300e-06
# Epoch 144/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1358
# Epoch 144: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1308 - val_loss: 16.3779 - learning_rate: 1.0000e-06
# Epoch 145/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1871
# Epoch 145: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 248ms/step - loss: 4.1647 - val_loss: 16.3546 - learning_rate: 1.0000e-06
# Epoch 146/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.0952
# Epoch 146: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.1550 - val_loss: 16.3459 - learning_rate: 1.0000e-06
# Epoch 147/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1850
# Epoch 147: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.2180 - val_loss: 16.3471 - learning_rate: 1.0000e-06
# Epoch 148/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.0862
# Epoch 148: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1161 - val_loss: 16.3439 - learning_rate: 1.0000e-06
# Epoch 149/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.0759
# Epoch 149: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1437 - val_loss: 16.3582 - learning_rate: 1.0000e-06
# Epoch 150/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.0787
# Epoch 150: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.1608 - val_loss: 16.3552 - learning_rate: 1.0000e-06
# Epoch 151/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1409
# Epoch 151: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1053 - val_loss: 16.3429 - learning_rate: 1.0000e-06
# Epoch 152/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1996
# Epoch 152: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 249ms/step - loss: 4.1614 - val_loss: 16.3463 - learning_rate: 1.0000e-06
# Epoch 153/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 4.1401
# Epoch 153: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 252ms/step - loss: 4.1680 - val_loss: 16.3577 - learning_rate: 1.0000e-06
# Epoch 154/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.2625
# Epoch 154: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.2090 - val_loss: 16.3378 - learning_rate: 1.0000e-06
# Epoch 155/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1417
# Epoch 155: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1565 - val_loss: 16.3615 - learning_rate: 1.0000e-06
# Epoch 156/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 4.1257
# Epoch 156: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 45s 253ms/step - loss: 4.1277 - val_loss: 16.3700 - learning_rate: 1.0000e-06
# Epoch 157/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.0874
# Epoch 157: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 247ms/step - loss: 4.1014 - val_loss: 16.3343 - learning_rate: 1.0000e-06
# Epoch 158/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.1783
# Epoch 158: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 4.1778 - val_loss: 16.3505 - learning_rate: 1.0000e-06
# Epoch 159/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 4.1516
# Epoch 159: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 45s 254ms/step - loss: 4.1719 - val_loss: 16.3561 - learning_rate: 1.0000e-06
# Epoch 160/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1286
# Epoch 160: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 248ms/step - loss: 4.1055 - val_loss: 16.3867 - learning_rate: 1.0000e-06
# Epoch 161/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1312
# Epoch 161: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1108 - val_loss: 16.3760 - learning_rate: 1.0000e-06
# Epoch 162/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 4.2241
# Epoch 162: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.1896 - val_loss: 16.3583 - learning_rate: 1.0000e-06
# Epoch 163/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.2754
# Epoch 163: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.2057 - val_loss: 16.3742 - learning_rate: 1.0000e-06
# Epoch 164/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1692
# Epoch 164: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1529 - val_loss: 16.3827 - learning_rate: 1.0000e-06
# Epoch 165/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1057
# Epoch 165: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1277 - val_loss: 16.3714 - learning_rate: 1.0000e-06
# Epoch 166/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1141
# Epoch 166: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1563 - val_loss: 16.3701 - learning_rate: 1.0000e-06
# Epoch 167/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1579
# Epoch 167: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1857 - val_loss: 16.3797 - learning_rate: 1.0000e-06
# Epoch 168/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.1267
# Epoch 168: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.1214 - val_loss: 16.3635 - learning_rate: 1.0000e-06
# Epoch 169/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.1270
# Epoch 169: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1355 - val_loss: 16.3901 - learning_rate: 1.0000e-06
# Epoch 170/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.2198
# Epoch 170: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1911 - val_loss: 16.3692 - learning_rate: 1.0000e-06
# Epoch 171/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1698
# Epoch 171: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.2108 - val_loss: 16.3768 - learning_rate: 1.0000e-06
# Epoch 172/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.2612
# Epoch 172: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1823 - val_loss: 16.3773 - learning_rate: 1.0000e-06
# Epoch 173/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.2342
# Epoch 173: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1914 - val_loss: 16.3875 - learning_rate: 1.0000e-06
# Epoch 174/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1782
# Epoch 174: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1746 - val_loss: 16.3789 - learning_rate: 1.0000e-06
# Epoch 175/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1962
# Epoch 175: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.2073 - val_loss: 16.3812 - learning_rate: 1.0000e-06
# Epoch 176/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1692
# Epoch 176: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1619 - val_loss: 16.3475 - learning_rate: 1.0000e-06
# Epoch 177/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1870
# Epoch 177: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1409 - val_loss: 16.3690 - learning_rate: 1.0000e-06
# Epoch 178/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.0943
# Epoch 178: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1784 - val_loss: 16.3562 - learning_rate: 1.0000e-06
# Epoch 179/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1536
# Epoch 179: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1256 - val_loss: 16.3544 - learning_rate: 1.0000e-06
# Epoch 180/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1032
# Epoch 180: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1487 - val_loss: 16.3759 - learning_rate: 1.0000e-06
# Epoch 181/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.1567
# Epoch 181: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1614 - val_loss: 16.3653 - learning_rate: 1.0000e-06
# Epoch 182/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1537
# Epoch 182: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1204 - val_loss: 16.3845 - learning_rate: 1.0000e-06
# Epoch 183/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1737
# Epoch 183: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.2001 - val_loss: 16.3811 - learning_rate: 1.0000e-06
# Epoch 184/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1390
# Epoch 184: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.1459 - val_loss: 16.3908 - learning_rate: 1.0000e-06
# Epoch 185/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1811
# Epoch 185: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 232ms/step - loss: 4.1878 - val_loss: 16.3725 - learning_rate: 1.0000e-06
# Epoch 186/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1310
# Epoch 186: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1679 - val_loss: 16.3609 - learning_rate: 1.0000e-06
# Epoch 187/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1522
# Epoch 187: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.1704 - val_loss: 16.3688 - learning_rate: 1.0000e-06
# Epoch 188/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1392
# Epoch 188: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.1323 - val_loss: 16.3621 - learning_rate: 1.0000e-06
# Epoch 189/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1583
# Epoch 189: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.1760 - val_loss: 16.3462 - learning_rate: 1.0000e-06
# Epoch 190/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.2399
# Epoch 190: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 45s 255ms/step - loss: 4.2389 - val_loss: 16.3534 - learning_rate: 1.0000e-06
# Epoch 191/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1240
# Epoch 191: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1271 - val_loss: 16.3495 - learning_rate: 1.0000e-06
# Epoch 192/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1086
# Epoch 192: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1260 - val_loss: 16.3625 - learning_rate: 1.0000e-06
# Epoch 193/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.2048
# Epoch 193: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 244ms/step - loss: 4.1777 - val_loss: 16.3289 - learning_rate: 1.0000e-06
# Epoch 194/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.2688
# Epoch 194: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1676 - val_loss: 16.3587 - learning_rate: 1.0000e-06
# Epoch 195/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1845
# Epoch 195: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1084 - val_loss: 16.3770 - learning_rate: 1.0000e-06
# Epoch 196/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1570
# Epoch 196: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1634 - val_loss: 16.3642 - learning_rate: 1.0000e-06
# Epoch 197/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.2128
# Epoch 197: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1675 - val_loss: 16.3657 - learning_rate: 1.0000e-06
# Epoch 198/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.2189
# Epoch 198: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1569 - val_loss: 16.3561 - learning_rate: 1.0000e-06
# Epoch 199/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1098
# Epoch 199: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1252 - val_loss: 16.3611 - learning_rate: 1.0000e-06
# Epoch 200/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.0395
# Epoch 200: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.0898 - val_loss: 16.3680 - learning_rate: 1.0000e-06
# Epoch 201/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.1400
# Epoch 201: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.1320 - val_loss: 16.3616 - learning_rate: 1.0000e-06
# Epoch 202/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.1886
# Epoch 202: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1824 - val_loss: 16.3513 - learning_rate: 1.0000e-06
# Epoch 203/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1062
# Epoch 203: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1402 - val_loss: 16.3613 - learning_rate: 1.0000e-06
# Epoch 204/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.1039
# Epoch 204: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1624 - val_loss: 16.3498 - learning_rate: 1.0000e-06
# Epoch 205/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1587
# Epoch 205: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1425 - val_loss: 16.3569 - learning_rate: 1.0000e-06
# Epoch 206/1000
# ...
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.1780
# Epoch 260: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1849 - val_loss: 16.3422 - learning_rate: 1.0000e-06
# Epoch 261/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1669
# Epoch 261: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.1498 - val_loss: 16.3668 - learning_rate: 1.0000e-06
# Epoch 262/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.2010
# Epoch 262: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1790 - val_loss: 16.3425 - learning_rate: 1.0000e-06
# Epoch 263/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1747
# Epoch 263: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1902 - val_loss: 16.3655 - learning_rate: 1.0000e-06
# Epoch 264/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1491
# Epoch 264: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1698 - val_loss: 16.3715 - learning_rate: 1.0000e-06
# Epoch 265/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 4.1034
# Epoch 265: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 242ms/step - loss: 4.1563 - val_loss: 16.3777 - learning_rate: 1.0000e-06
# Epoch 266/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1339
# Epoch 266: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 248ms/step - loss: 4.1492 - val_loss: 16.3814 - learning_rate: 1.0000e-06
# Epoch 267/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.0702
# Epoch 267: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - loss: 4.1394 - val_loss: 16.3728 - learning_rate: 1.0000e-06
# Epoch 268/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.2635
# Epoch 268: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.1924 - val_loss: 16.3547 - learning_rate: 1.0000e-06
# Epoch 269/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.2465
# Epoch 269: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 250ms/step - loss: 4.1630 - val_loss: 16.3393 - learning_rate: 1.0000e-06
# Epoch 270/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1340
# Epoch 270: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1585 - val_loss: 16.3676 - learning_rate: 1.0000e-06
# Epoch 271/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 4.2260
# Epoch 271: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.2074 - val_loss: 16.3839 - learning_rate: 1.0000e-06
# Epoch 272/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1319
# Epoch 272: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.1694 - val_loss: 16.3891 - learning_rate: 1.0000e-06
# Epoch 273/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 4.1380
# Epoch 273: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 250ms/step - loss: 4.1618 - val_loss: 16.3645 - learning_rate: 1.0000e-06
# Epoch 274/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 4.1198
# Epoch 274: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 247ms/step - loss: 4.1315 - val_loss: 16.3678 - learning_rate: 1.0000e-06
# Epoch 275/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 4.1547
# Epoch 275: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - loss: 4.1775 - val_loss: 16.3531 - learning_rate: 1.0000e-06
# Epoch 276/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.0985
# Epoch 276: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 239ms/step - loss: 4.0923 - val_loss: 16.3698 - learning_rate: 1.0000e-06
# Epoch 277/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 4.2114
# Epoch 277: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 44s 248ms/step - loss: 4.1570 - val_loss: 16.3762 - learning_rate: 1.0000e-06
# Epoch 278/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1351
# Epoch 278: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 43s 243ms/step - loss: 4.1555 - val_loss: 16.3753 - learning_rate: 1.0000e-06
# Epoch 279/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 4.2168
# Epoch 279: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 45s 257ms/step - loss: 4.1714 - val_loss: 16.3797 - learning_rate: 1.0000e-06
# Epoch 280/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1201
# Epoch 280: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1444 - val_loss: 16.3887 - learning_rate: 1.0000e-06
# Epoch 281/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 4.1291
# Epoch 281: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 39s 225ms/step - loss: 4.1324 - val_loss: 16.3952 - learning_rate: 1.0000e-06
# Epoch 282/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.0971
# Epoch 282: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1560 - val_loss: 16.3694 - learning_rate: 1.0000e-06
# Epoch 283/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1679
# Epoch 283: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1625 - val_loss: 16.3651 - learning_rate: 1.0000e-06
# Epoch 284/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1478
# Epoch 284: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1686 - val_loss: 16.3670 - learning_rate: 1.0000e-06
# Epoch 285/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1620
# Epoch 285: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1640 - val_loss: 16.3776 - learning_rate: 1.0000e-06
# Epoch 286/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.0721
# Epoch 286: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1126 - val_loss: 16.3623 - learning_rate: 1.0000e-06
# Epoch 287/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 4.1861
# Epoch 287: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.1869 - val_loss: 16.3621 - learning_rate: 1.0000e-06
# Epoch 288/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1196
# Epoch 288: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1261 - val_loss: 16.3644 - learning_rate: 1.0000e-06
# Epoch 289/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.1161
# Epoch 289: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1438 - val_loss: 16.3818 - learning_rate: 1.0000e-06
# Epoch 290/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1542
# Epoch 290: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1489 - val_loss: 16.3841 - learning_rate: 1.0000e-06
# Epoch 291/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1776
# Epoch 291: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1643 - val_loss: 16.3685 - learning_rate: 1.0000e-06
# Epoch 292/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.0931
# Epoch 292: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1120 - val_loss: 16.3695 - learning_rate: 1.0000e-06
# Epoch 293/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.1229
# Epoch 293: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.1326 - val_loss: 16.3572 - learning_rate: 1.0000e-06
# Epoch 294/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.0791
# Epoch 294: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.1036 - val_loss: 16.3557 - learning_rate: 1.0000e-06
# Epoch 295/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 4.1514
# Epoch 295: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1460 - val_loss: 16.3643 - learning_rate: 1.0000e-06
# Epoch 296/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1686
# Epoch 296: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1523 - val_loss: 16.3930 - learning_rate: 1.0000e-06
# Epoch 297/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.1367
# Epoch 297: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 230ms/step - loss: 4.0873 - val_loss: 16.3753 - learning_rate: 1.0000e-06
# Epoch 298/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 4.0735
# Epoch 298: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.1052 - val_loss: 16.3655 - learning_rate: 1.0000e-06
# Epoch 299/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 4.1582
# Epoch 299: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 240ms/step - loss: 4.1772 - val_loss: 16.3653 - learning_rate: 1.0000e-06
# Epoch 300/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 4.1862
# Epoch 300: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 38s 215ms/step - loss: 4.1603 - val_loss: 16.3654 - learning_rate: 1.0000e-06
# Epoch 301/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 4.1089
# Epoch 301: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 36s 203ms/step - loss: 4.1288 - val_loss: 16.3746 - learning_rate: 1.0000e-06
# Epoch 302/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 4.1640
# Epoch 302: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 38s 216ms/step - loss: 4.1589 - val_loss: 16.3571 - learning_rate: 1.0000e-06
# Epoch 303/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 4.1396
# Epoch 303: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 241ms/step - loss: 4.1288 - val_loss: 16.3483 - learning_rate: 1.0000e-06
# Epoch 304/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1635
# Epoch 304: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1176 - val_loss: 16.3676 - learning_rate: 1.0000e-06
# Epoch 305/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.1434
# Epoch 305: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1030 - val_loss: 16.3654 - learning_rate: 1.0000e-06
# Epoch 306/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 4.0666
# Epoch 306: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.1363 - val_loss: 16.3613 - learning_rate: 1.0000e-06
# Epoch 307/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 4.0578
# Epoch 307: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1009 - val_loss: 16.3590 - learning_rate: 1.0000e-06
# Epoch 308/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.1674
# Epoch 308: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 228ms/step - loss: 4.1339 - val_loss: 16.3477 - learning_rate: 1.0000e-06
# Epoch 309/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.0581
# Epoch 309: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.0999 - val_loss: 16.3652 - learning_rate: 1.0000e-06
# Epoch 310/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1642
# Epoch 310: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.2014 - val_loss: 16.3680 - learning_rate: 1.0000e-06
# Epoch 311/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1819
# Epoch 311: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1692 - val_loss: 16.3800 - learning_rate: 1.0000e-06
# Epoch 312/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1880
# Epoch 312: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1706 - val_loss: 16.3752 - learning_rate: 1.0000e-06
# Epoch 313/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.0813
# Epoch 313: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 235ms/step - loss: 4.1253 - val_loss: 16.3653 - learning_rate: 1.0000e-06
# Epoch 314/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.1227
# Epoch 314: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 227ms/step - loss: 4.1866 - val_loss: 16.3801 - learning_rate: 1.0000e-06
# Epoch 315/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 4.1485
# Epoch 315: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 237ms/step - loss: 4.1498 - val_loss: 16.3784 - learning_rate: 1.0000e-06
# Epoch 316/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.1265
# Epoch 316: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.1353 - val_loss: 16.3635 - learning_rate: 1.0000e-06
# Epoch 317/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 4.2310
# Epoch 317: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 231ms/step - loss: 4.2322 - val_loss: 16.3536 - learning_rate: 1.0000e-06
# Epoch 318/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 4.2209
# Epoch 318: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - loss: 4.2032 - val_loss: 16.3730 - learning_rate: 1.0000e-06
# Epoch 319/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1138
# Epoch 319: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 234ms/step - loss: 4.1126 - val_loss: 16.3641 - learning_rate: 1.0000e-06
# Epoch 320/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 4.1705
# Epoch 320: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 236ms/step - loss: 4.1502 - val_loss: 16.3598 - learning_rate: 1.0000e-06
# Epoch 321/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 4.2394
# Epoch 321: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 41s 233ms/step - loss: 4.1969 - val_loss: 16.3489 - learning_rate: 1.0000e-06
# Epoch 322/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 4.1346
# Epoch 322: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1604 - val_loss: 16.3717 - learning_rate: 1.0000e-06
# Epoch 323/1000
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 4.1089
# Epoch 323: val_loss did not improve from 13.61778
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 42s 238ms/step - loss: 4.1293 - val_loss: 16.3681 - learning_rate: 1.0000e-06
# Epoch 323: early stopping
# Restoring model weights from the end of the best epoch: 23.
# /opt/miniconda3/envs/ai_new/lib/python3.11/site-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'attention', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
#
# ================ [PERFORMANCE METRICS] ================
# RMSE : 19.37 cycles
# MAE  : 13.33 cycles
# R2   : 0.7722
# MAPE : 39.47 %
#
# =========== [FAILURE PREDICTION ANALYSIS] ===========
# Failure Threshold: < 30 cycles
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.98      0.97       108
#      Failure       0.97      0.93      0.95        60
#
#     accuracy                           0.96       168
#    macro avg       0.96      0.96      0.96       168
# weighted avg       0.96      0.96      0.96       168
#
# Confusion Matrix Layout:
# True_Negative(Correct_Normal)   : 106
# False_Positive(False_Alarm)     : 2
# False_Negative(Missed_Failure)  : 4
# True_Positive(Detected_Failure) : 56

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, mean_absolute_error, r2_score
from pykalman import KalmanFilter

# --- 1. 설정 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
epochs = 1000 
es_patience = 50   
lr_patience = 10

columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
# 요청하신 드랍 컬럼 반영
cols_to_drop = ['setting3', 's13', 's19']

# --- 2. 전처리 함수 정의 ---
def load_train_data():
    print("📢 1. Train 데이터 로딩 및 전처리 중...")
    df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_train.drop(columns=cols_to_drop, inplace=True)
    
    # Train RUL 계산
    df_max = df_train.groupby('engine_id')['cycle'].max().reset_index()
    df_train = df_train.merge(df_max.rename(columns={'cycle': 'max_cycle'}), on='engine_id')
    df_train['RUL'] = df_train['max_cycle'] - df_train['cycle']
    
    features = [c for c in df_train.columns if c not in ['engine_id', 'cycle', 'max_cycle', 'RUL']]
    
    # Scaler 학습 및 적용
    scaler = MinMaxScaler()
    df_train[features] = scaler.fit_transform(df_train[features])
    
    # 칼만 필터 적용 (Train)
    print("   - Train 데이터 칼만 필터링 적용 중...")
    for engine_id in df_train['engine_id'].unique():
        idx = df_train[df_train['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_train.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_train.loc[idx, features].values)
        df_train.loc[idx, features] = state_means
        
    return df_train, features, scaler

def load_test_data(features, scaler):
    print("📢 2. 진짜 Test 및 RUL 데이터 로딩 중...")
    df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_test.drop(columns=cols_to_drop, inplace=True)
    
    # Data Leakage 방지: Train Scaler로 transform만 수행
    df_test[features] = scaler.transform(df_test[features])
    
    # 칼만 필터 적용 (Test)
    print("   - Test 데이터 칼만 필터링 적용 중...")
    for engine_id in df_test['engine_id'].unique():
        idx = df_test[df_test['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_test.loc[idx, features].values)
        df_test.loc[idx, features] = state_means
        
    # RUL 정답지 로드
    df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
    df_rul['engine_id'] = df_rul.index + 1
    
    X_test_real, y_test_real = [], []
    
    # 각 테스트 엔진의 마지막 시점 기준 과거 sequence_length 만큼 시퀀스 추출
    for id in df_test['engine_id'].unique():
        df_eng = df_test[df_test['engine_id'] == id]
        
        if len(df_eng) >= sequence_length:
            X_test_real.append(df_eng[features].values[-sequence_length:])
            real_rul_val = df_rul[df_rul['engine_id'] == id]['true_rul'].values[0]
            y_test_real.append(real_rul_val)
            
    return np.array(X_test_real), np.array(y_test_real)

# --- 3. Dual-Pooling Small Transformer 모델 정의 ---
def build_refined_small_model(input_shape):
    inputs = layers.Input(shape=input_shape)
    
    # 1. 초기 임베딩 (64차원)
    x = layers.Dense(64, activation="relu")(inputs)
    
    # 2. 3개 블록 구성
    for _ in range(3):
        # Attention: (64차원 -> 64차원)
        attn = layers.MultiHeadAttention(key_dim=16, num_heads=4, dropout=0.1)(x, x)
        x = layers.Add()([x, attn])
        x = layers.LayerNormalization(epsilon=1e-6)(x)
        
        # Feed Forward: (64 -> 192 -> 64)
        x_ff = layers.Conv1D(filters=192, kernel_size=1, activation="relu")(x)
        x_ff = layers.Dropout(0.1)(x_ff)
        x_ff = layers.Conv1D(filters=64, kernel_size=1)(x_ff)
        
        x = layers.Add()([x, x_ff])
        x = layers.LayerNormalization(epsilon=1e-6)(x)

    # 3. Dual Pooling (Trend + Peak 추출)
    x_avg = layers.GlobalAveragePooling1D()(x)
    x_max = layers.GlobalMaxPooling1D()(x)
    x = layers.Concatenate()([x_avg, x_max])
    
    # 4. 최종 출력
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(1)(x)
    
    model = models.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001, weight_decay=0.004)
    model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=1.0))
    return model

# --- 4. 데이터 세트 빌드 ---
df_train, features, scaler = load_train_data()

X_all, y_all = [], []
for id in df_train['engine_id'].unique():
    df_eng = df_train[df_train['engine_id'] == id]
    for i in range(len(df_eng) - sequence_length + 1):
        X_all.append(df_eng[features].values[i:i+sequence_length])
        y_all.append(df_eng['RUL'].values[i+sequence_length-1])
X_all, y_all = np.array(X_all), np.array(y_all)

# Train 내부 Validation 분할 (80:20)
split_idx = int(len(X_all) * 0.8)
X_train, X_val = X_all[:split_idx], X_all[split_idx:]
y_train, y_val = y_all[:split_idx], y_all[split_idx:]

# 진짜 평가용 테스트 데이터 세트 가져오기
X_test_real, y_test_real = load_test_data(features, scaler)

# --- 5. 학습 진행 ---
model = build_refined_small_model((sequence_length, len(features)))

checkpoint = callbacks.ModelCheckpoint(
    filepath='best_transformer_model_small.keras',
    monitor='val_loss', save_best_only=True, verbose=1
)

callbacks_list = [
    callbacks.EarlyStopping(monitor='val_loss', patience=es_patience, restore_best_weights=True, verbose=1),
    callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=lr_patience, min_lr=0.000001, verbose=1),
    checkpoint
]

history = model.fit(
    X_train, y_train, epochs=epochs, batch_size=128, 
    validation_data=(X_val, y_val), callbacks=callbacks_list, verbose=1
)

# 검증 완료된 최고 성능 모델 가중치 복원
model = models.load_model('best_transformer_model_small.keras')

# --- 6. 진짜 테스트 데이터 기반 최종 평가 및 결과 출력 ---
y_pred = model.predict(X_test_real).flatten()

# 회귀 지표 계산
rmse = np.sqrt(mean_squared_error(y_test_real, y_pred))
mae = mean_absolute_error(y_test_real, y_pred)
r2 = r2_score(y_test_real, y_pred)
non_zero_mask = y_test_real > 0
mape = np.mean(np.abs((y_test_real[non_zero_mask] - y_pred[non_zero_mask]) / y_test_real[non_zero_mask])) * 100

print("\n================ [PERFORMANCE METRICS] ================")
print(f"RMSE : {rmse:.2f} cycles")
print(f"MAE  : {mae:.2f} cycles")
print(f"R2   : {r2:.4f}")
print(f"MAPE : {mape:.2f} %")

# 분류 지표 (고장 기준: 30 cycle 이하)
threshold = 30
y_true_cls = (y_test_real < threshold).astype(int)
y_pred_cls = (y_pred < threshold).astype(int)
cls_report = classification_report(y_true_cls, y_pred_cls, target_names=['Normal', 'Failure'])
cm = confusion_matrix(y_true_cls, y_pred_cls)

print("\n=========== [FAILURE PREDICTION ANALYSIS] ===========")
print(f"Failure Threshold: < {threshold} cycles")
print("Classification Report:")
print(cls_report)

print("Confusion Matrix Layout:")
print(f"True_Negative(Correct_Normal)   : {cm[0,0]}")
print(f"False_Positive(False_Alarm)     : {cm[0,1]}")
print(f"False_Negative(Missed_Failure)  : {cm[1,0]}")
print(f"True_Positive(Detected_Failure) : {cm[1,1]}")

# 시각화
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Training Loss')
plt.legend()

plt.subplot(1, 2, 2)
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', xticklabels=['Normal', 'Failure'], yticklabels=['Normal', 'Failure'])
plt.title('Confusion Matrix (Real Test)')
plt.show()
# Out:
# 📢 1. Train 데이터 로딩 및 전처리 중...
#    - Train 데이터 칼만 필터링 적용 중...
# 📢 2. 진짜 Test 및 RUL 데이터 로딩 중...
#    - Test 데이터 칼만 필터링 적용 중...
# Epoch 1/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 43.9904
# Epoch 1: val_loss improved from None to 25.79067, saving model to best_transformer_model_small.keras
#
# Epoch 1: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 31s 159ms/step - loss: 36.0591 - val_loss: 25.7907 - learning_rate: 0.0010
# Epoch 2/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 26.7333
# Epoch 2: val_loss improved from 25.79067 to 24.82020, saving model to best_transformer_model_small.keras
#
# Epoch 2: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - loss: 26.4206 - val_loss: 24.8202 - learning_rate: 0.0010
# Epoch 3/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 24.5873
# Epoch 3: val_loss improved from 24.82020 to 20.28873, saving model to best_transformer_model_small.keras
#
# Epoch 3: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - loss: 23.6678 - val_loss: 20.2887 - learning_rate: 0.0010
# Epoch 4/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 20.9738
# Epoch 4: val_loss improved from 20.28873 to 17.32445, saving model to best_transformer_model_small.keras
#
# Epoch 4: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 155ms/step - loss: 20.0255 - val_loss: 17.3244 - learning_rate: 0.0010
# Epoch 5/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 17.2897
# Epoch 5: val_loss improved from 17.32445 to 14.84590, saving model to best_transformer_model_small.keras
#
# Epoch 5: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 156ms/step - loss: 16.7577 - val_loss: 14.8459 - learning_rate: 0.0010
# Epoch 6/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 15.3789
# Epoch 6: val_loss improved from 14.84590 to 14.09784, saving model to best_transformer_model_small.keras
#
# Epoch 6: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 154ms/step - loss: 14.8308 - val_loss: 14.0978 - learning_rate: 0.0010
# Epoch 7/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 14.2144
# Epoch 7: val_loss did not improve from 14.09784
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - loss: 13.5929 - val_loss: 14.1463 - learning_rate: 0.0010
# Epoch 8/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 13.1687
# Epoch 8: val_loss did not improve from 14.09784
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - loss: 13.2103 - val_loss: 14.5556 - learning_rate: 0.0010
# Epoch 9/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 11.7446
# Epoch 9: val_loss improved from 14.09784 to 12.42258, saving model to best_transformer_model_small.keras
#
# Epoch 9: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 11.6725 - val_loss: 12.4226 - learning_rate: 0.0010
# Epoch 10/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 11.8749
# Epoch 10: val_loss improved from 12.42258 to 12.39462, saving model to best_transformer_model_small.keras
#
# Epoch 10: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 11.6255 - val_loss: 12.3946 - learning_rate: 0.0010
# Epoch 11/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 10.8278
# Epoch 11: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 10.5806 - val_loss: 12.5403 - learning_rate: 0.0010
# Epoch 12/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 11.0781
# Epoch 12: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 155ms/step - loss: 10.6770 - val_loss: 12.8474 - learning_rate: 0.0010
# Epoch 13/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 10.2162
# Epoch 13: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - loss: 10.3836 - val_loss: 12.9996 - learning_rate: 0.0010
# Epoch 14/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 10.2718
# Epoch 14: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 157ms/step - loss: 9.8457 - val_loss: 13.7188 - learning_rate: 0.0010
# Epoch 15/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 9.9969
# Epoch 15: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 157ms/step - loss: 9.7325 - val_loss: 20.6992 - learning_rate: 0.0010
# Epoch 16/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 9.6911
# Epoch 16: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 156ms/step - loss: 9.2419 - val_loss: 14.5546 - learning_rate: 0.0010
# Epoch 17/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 8.8888
# Epoch 17: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 158ms/step - loss: 8.7752 - val_loss: 13.3111 - learning_rate: 0.0010
# Epoch 18/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 8.6362
# Epoch 18: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 155ms/step - loss: 8.4647 - val_loss: 16.0852 - learning_rate: 0.0010
# Epoch 19/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 8.8502
# Epoch 19: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 8.4131 - val_loss: 12.5815 - learning_rate: 0.0010
# Epoch 20/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 8.4672
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 20: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 8.4037 - val_loss: 14.3977 - learning_rate: 0.0010
# Epoch 21/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 7.2922
# Epoch 21: val_loss did not improve from 12.39462
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 7.0222 - val_loss: 12.5968 - learning_rate: 3.0000e-04
# Epoch 22/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 6.8066
# Epoch 22: val_loss improved from 12.39462 to 12.34572, saving model to best_transformer_model_small.keras
#
# Epoch 22: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 6.8424 - val_loss: 12.3457 - learning_rate: 3.0000e-04
# Epoch 23/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 6.8300
# Epoch 23: val_loss did not improve from 12.34572
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 6.7739 - val_loss: 12.3712 - learning_rate: 3.0000e-04
# Epoch 24/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.6780
# Epoch 24: val_loss did not improve from 12.34572
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.6672 - val_loss: 12.9850 - learning_rate: 3.0000e-04
# Epoch 25/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 6.6303
# Epoch 25: val_loss did not improve from 12.34572
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 6.6125 - val_loss: 12.8695 - learning_rate: 3.0000e-04
# Epoch 26/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 6.5008
# Epoch 26: val_loss improved from 12.34572 to 12.18114, saving model to best_transformer_model_small.keras
#
# Epoch 26: finished saving model to best_transformer_model_small.keras
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 6.5042 - val_loss: 12.1811 - learning_rate: 3.0000e-04
# Epoch 27/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 6.5123
# Epoch 27: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.5431 - val_loss: 13.6330 - learning_rate: 3.0000e-04
# Epoch 28/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 6.5441
# Epoch 28: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.4205 - val_loss: 13.3386 - learning_rate: 3.0000e-04
# Epoch 29/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 6.4639
# Epoch 29: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - loss: 6.3397 - val_loss: 12.9414 - learning_rate: 3.0000e-04
# Epoch 30/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 6.3863
# Epoch 30: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 6.3290 - val_loss: 12.9006 - learning_rate: 3.0000e-04
# Epoch 31/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.5071
# Epoch 31: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.3869 - val_loss: 13.3211 - learning_rate: 3.0000e-04
# Epoch 32/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 6.2439
# Epoch 32: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 6.2073 - val_loss: 14.0226 - learning_rate: 3.0000e-04
# Epoch 33/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.3447
# Epoch 33: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.2421 - val_loss: 13.7413 - learning_rate: 3.0000e-04
# Epoch 34/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 6.0751
# Epoch 34: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 6.0530 - val_loss: 13.3215 - learning_rate: 3.0000e-04
# Epoch 35/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.1527
# Epoch 35: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 6.1450 - val_loss: 13.3005 - learning_rate: 3.0000e-04
# Epoch 36/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 6.3293
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 36: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 6.1554 - val_loss: 15.0532 - learning_rate: 3.0000e-04
# Epoch 37/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.8211
# Epoch 37: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.7456 - val_loss: 13.7640 - learning_rate: 9.0000e-05
# Epoch 38/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.6316
# Epoch 38: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.6268 - val_loss: 13.5546 - learning_rate: 9.0000e-05
# Epoch 39/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.6065
# Epoch 39: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.5623 - val_loss: 13.9121 - learning_rate: 9.0000e-05
# Epoch 40/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 5.5252
# Epoch 40: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.5510 - val_loss: 13.4356 - learning_rate: 9.0000e-05
# Epoch 41/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 5.5851
# Epoch 41: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 5.5854 - val_loss: 13.7003 - learning_rate: 9.0000e-05
# Epoch 42/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.5863
# Epoch 42: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.6098 - val_loss: 13.7676 - learning_rate: 9.0000e-05
# Epoch 43/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.5314
# Epoch 43: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.4952 - val_loss: 13.5572 - learning_rate: 9.0000e-05
# Epoch 44/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.5266
# Epoch 44: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.4688 - val_loss: 13.9203 - learning_rate: 9.0000e-05
# Epoch 45/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 5.3828
# Epoch 45: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - loss: 5.5076 - val_loss: 13.2856 - learning_rate: 9.0000e-05
# Epoch 46/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.5037
# Epoch 46: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 46: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.4570 - val_loss: 13.8985 - learning_rate: 9.0000e-05
# Epoch 47/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 5.3408
# Epoch 47: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - loss: 5.3565 - val_loss: 13.2898 - learning_rate: 2.7000e-05
# Epoch 48/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.3930
# Epoch 48: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.3837 - val_loss: 13.5885 - learning_rate: 2.7000e-05
# Epoch 49/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.3674
# Epoch 49: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 5.3337 - val_loss: 13.2309 - learning_rate: 2.7000e-05
# Epoch 50/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.3469
# Epoch 50: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 5.3600 - val_loss: 13.6468 - learning_rate: 2.7000e-05
# Epoch 51/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 5.2699
# Epoch 51: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - loss: 5.2639 - val_loss: 13.4711 - learning_rate: 2.7000e-05
# Epoch 52/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 5.2946
# Epoch 52: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 155ms/step - loss: 5.3335 - val_loss: 13.4512 - learning_rate: 2.7000e-05
# Epoch 53/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 5.3387
# Epoch 53: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 5.3234 - val_loss: 13.5981 - learning_rate: 2.7000e-05
# Epoch 54/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.1736
# Epoch 54: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 146ms/step - loss: 5.2907 - val_loss: 13.7181 - learning_rate: 2.7000e-05
# Epoch 55/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.3273
# Epoch 55: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 5.3187 - val_loss: 13.2770 - learning_rate: 2.7000e-05
# Epoch 56/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.2813
# Epoch 56: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 56: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 146ms/step - loss: 5.2630 - val_loss: 13.6942 - learning_rate: 2.7000e-05
# Epoch 57/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 5.3255
# Epoch 57: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 145ms/step - loss: 5.2775 - val_loss: 13.5501 - learning_rate: 8.1000e-06
# Epoch 58/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 5.2554
# Epoch 58: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 145ms/step - loss: 5.2476 - val_loss: 13.4837 - learning_rate: 8.1000e-06
# Epoch 59/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 5.2846
# Epoch 59: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 5.2665 - val_loss: 13.5340 - learning_rate: 8.1000e-06
# Epoch 60/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 5.3230
# Epoch 60: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 5.2586 - val_loss: 13.5861 - learning_rate: 8.1000e-06
# Epoch 61/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 5.2263
# Epoch 61: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 147ms/step - loss: 5.2350 - val_loss: 13.5274 - learning_rate: 8.1000e-06
# Epoch 62/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.2731
# Epoch 62: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 5.2568 - val_loss: 13.4958 - learning_rate: 8.1000e-06
# Epoch 63/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.2058
# Epoch 63: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - loss: 5.2167 - val_loss: 13.7628 - learning_rate: 8.1000e-06
# Epoch 64/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 5.2392
# Epoch 64: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 152ms/step - loss: 5.2497 - val_loss: 13.5464 - learning_rate: 8.1000e-06
# Epoch 65/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.2907
# Epoch 65: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.2803 - val_loss: 13.5479 - learning_rate: 8.1000e-06
# Epoch 66/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 5.2853
# Epoch 66: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 66: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 153ms/step - loss: 5.2115 - val_loss: 13.5742 - learning_rate: 8.1000e-06
# Epoch 67/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.2224
# Epoch 67: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.2277 - val_loss: 13.6009 - learning_rate: 2.4300e-06
# Epoch 68/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 5.2698
# Epoch 68: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - loss: 5.2062 - val_loss: 13.5225 - learning_rate: 2.4300e-06
# Epoch 69/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.1730
# Epoch 69: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.2143 - val_loss: 13.6843 - learning_rate: 2.4300e-06
# Epoch 70/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 5.2941
# Epoch 70: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 157ms/step - loss: 5.2394 - val_loss: 13.5088 - learning_rate: 2.4300e-06
# Epoch 71/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.2426
# Epoch 71: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.2380 - val_loss: 13.6254 - learning_rate: 2.4300e-06
# Epoch 72/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 5.2337
# Epoch 72: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.2790 - val_loss: 13.5257 - learning_rate: 2.4300e-06
# Epoch 73/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 5.2828
# Epoch 73: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.2172 - val_loss: 13.5123 - learning_rate: 2.4300e-06
# Epoch 74/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 5.2561
# Epoch 74: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - loss: 5.2189 - val_loss: 13.5386 - learning_rate: 2.4300e-06
# Epoch 75/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 5.2181
# Epoch 75: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 28s 157ms/step - loss: 5.2316 - val_loss: 13.5814 - learning_rate: 2.4300e-06
# Epoch 76/1000
# 175/176 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 5.2175
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 76: val_loss did not improve from 12.18114
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - loss: 5.2408 - val_loss: 13.6260 - learning_rate: 2.4300e-06
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
#
# ================ [PERFORMANCE METRICS] ================
# RMSE : 18.62 cycles
# MAE  : 11.85 cycles
# R2   : 0.7894
# MAPE : 24.25 %
#
# =========== [FAILURE PREDICTION ANALYSIS] ===========
# Failure Threshold: < 30 cycles
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.98       108
#      Failure       0.92      1.00      0.96        60
#
#     accuracy                           0.97       168
#    macro avg       0.96      0.98      0.97       168
# weighted avg       0.97      0.97      0.97       168
#
# Confusion Matrix Layout:
# True_Negative(Correct_Normal)   : 103
# False_Positive(False_Alarm)     : 5
# False_Negative(Missed_Failure)  : 0
# True_Positive(Detected_Failure) : 60

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error, mean_absolute_error, r2_score
from pykalman import KalmanFilter

# --- 1. 설정 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
cols_to_drop = ['setting3', 's13', 's19']

# 💡 [필수] LSTM 복원용 커스텀 레이어 프레임
@tf.keras.utils.register_keras_serializable()
class Attention(layers.Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dense = layers.Dense(1, activation='tanh')
    def call(self, inputs):
        score = self.dense(inputs)
        weights = tf.nn.softmax(score, axis=1)
        return tf.reduce_sum(inputs * weights, axis=1)

# --- 2. NASA 공식 비대칭 페널티 스코어 함수 정의 ---
def calculate_nasa_score(y_true, y_pred):
    d = y_pred - y_true
    score = 0.0
    for di in d:
        if di < 0:
            score += (np.exp(-di / 13.0) - 1.0)
        else:
            score += (np.exp(di / 10.0) - 1.0)
    return score

# --- 3. 전처리 함수 정의 ---
def get_scaler_and_features():
    df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_train.drop(columns=cols_to_drop, inplace=True)
    features = [c for c in df_train.columns if c not in ['engine_id', 'cycle']]
    scaler = MinMaxScaler()
    scaler.fit(df_train[features])
    return scaler, features

def load_test_data(features, scaler):
    df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_test.drop(columns=cols_to_drop, inplace=True)
    df_test[features] = scaler.transform(df_test[features])
    
    for engine_id in df_test['engine_id'].unique():
        idx = df_test[df_test['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_test.loc[idx, features].values)
        df_test.loc[idx, features] = state_means
        
    df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
    df_rul['engine_id'] = df_rul.index + 1
    
    X_test_real, y_test_real = [], []
    for id in df_test['engine_id'].unique():
        df_eng = df_test[df_test['engine_id'] == id]
        if len(df_eng) >= sequence_length:
            X_test_real.append(df_eng[features].values[-sequence_length:])
            y_test_real.append(df_rul[df_rul['engine_id'] == id]['true_rul'].values[0])
            
    return np.array(X_test_real), np.array(y_test_real)

# --- 4. 종합 평가 함수 정의 ---
def evaluate_model_performance(model_name, y_true, y_pred, threshold=30):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    nasa_score = calculate_nasa_score(y_true, y_pred)

    print(f"\n================ [{model_name.upper()} PERFORMANCE METRICS] ================")
    print(f"🥇 NASA Penalty Score : {nasa_score:.2f}")
    print(f"RMSE : {rmse:.2f} cycles")
    print(f"MAE  : {mae:.2f} cycles")
    print(f"R2   : {r2:.4f}")

    y_true_cls = (y_true < threshold).astype(int)
    y_pred_cls = (y_pred < threshold).astype(int)
    cm = confusion_matrix(y_true_cls, y_pred_cls)
    return cm, nasa_score

# --- 5. 가동 및 추론 ---
scaler, features = get_scaler_and_features()
X_test_real, y_test_real = load_test_data(features, scaler)

print("\n📢 저장된 가중치 파일에서 모델 복원 및 추론 시작...")
model_lstm = models.load_model('best_model.keras', custom_objects={'Attention': Attention})
y_pred_lstm = model_lstm.predict(X_test_real).flatten()
cm_lstm, nasa_lstm = evaluate_model_performance("Conv1D-BiLSTM-Attention", y_test_real, y_pred_lstm)

model_trans = models.load_model('best_transformer_model_small.keras')
y_pred_trans = model_trans.predict(X_test_real).flatten()
cm_trans, nasa_trans = evaluate_model_performance("Dual-Pooling-Transformer", y_test_real, y_pred_trans)


# --- 6. 3x2 초정밀 마스터 대시보드 시각화 ---
plt.figure(figsize=(18, 16))

# Plot 1: LSTM Confusion Matrix
plt.subplot(3, 2, 1)
sns.heatmap(cm_lstm, annot=True, fmt='d', cmap='Oranges', xticklabels=['Normal', 'Failure'], yticklabels=['Normal', 'Failure'])
plt.title('1. Confusion Matrix: LSTM-Attention', fontsize=12, fontweight='bold')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')

# Plot 2: Transformer Confusion Matrix
plt.subplot(3, 2, 2)
sns.heatmap(cm_trans, annot=True, fmt='d', cmap='Purples', xticklabels=['Normal', 'Failure'], yticklabels=['Normal', 'Failure'])
plt.title('2. Confusion Matrix: Dual-Pooling Transformer', fontsize=12, fontweight='bold')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')

# Plot 3: RUL 추종 경향 곡선 (정답 크기순 정렬)
plt.subplot(3, 2, 3)
df_plot = pd.DataFrame({'True': y_test_real, 'LSTM': y_pred_lstm, 'Trans': y_pred_trans}).sort_values(by='True').reset_index(drop=True)
plt.plot(df_plot['True'], label='True RUL', color='black', linewidth=2.5, linestyle='--')
plt.plot(df_plot['LSTM'], label='LSTM-Attention Pred', color='darkorange', alpha=0.7)
plt.plot(df_plot['Trans'], label='Transformer Pred', color='mediumpurple', alpha=0.7)
plt.title('3. RUL Prediction Trend (Sorted by True RUL)', fontsize=12, fontweight='bold')
plt.xlabel('Engine Test Samples')
plt.ylabel('RUL (Cycles)')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 4: 잔차 오차 분포 (KDE)
plt.subplot(3, 2, 4)
sns.kdeplot(y_test_real - y_pred_lstm, label='LSTM-Attention Error', color='darkorange', fill=True, alpha=0.15)
sns.kdeplot(y_test_real - y_pred_trans, label='Transformer Error', color='mediumpurple', fill=True, alpha=0.15)
plt.axvline(x=0, color='red', linestyle=':', linewidth=2, label='Perfect Prediction')
plt.title('4. Residuals (Error) Distribution Comparison', fontsize=12, fontweight='bold')
plt.xlabel('Error (True - Pred)')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 5: [신규] True vs Predicted 산점도 비교
plt.subplot(3, 2, 5)
plt.scatter(y_test_real, y_pred_lstm, color='darkorange', alpha=0.6, label='LSTM-Attention', edgecolors='w', s=40)
plt.scatter(y_test_real, y_pred_trans, color='mediumpurple', alpha=0.6, label='Transformer', edgecolors='w', s=40)
max_val = int(max(max(y_test_real), max(y_pred_lstm), max(y_pred_trans)))
plt.plot([0, max_val], [0, max_val], 'k--', linewidth=2, label='y = x (Ideal)')
plt.title('5. True RUL vs Predicted RUL Scatter Plot', fontsize=12, fontweight='bold')
plt.xlabel('True RUL (Cycles)')
plt.ylabel('Predicted RUL (Cycles)')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 6: [신규] NASA 공식 Penalty Score 비대칭 비교 바 차트
plt.subplot(3, 2, 6)
bars = plt.bar(['LSTM-Attention', 'Dual-Pooling Transformer'], [nasa_lstm, nasa_trans], color=['darkorange', 'mediumpurple'], width=0.5)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + (yval*0.01), f"{yval:,.2f}", ha='center', va='bottom', fontweight='bold')
plt.title('6. NASA Penalty Score Comparison (Lower is Better)', fontsize=12, fontweight='bold')
plt.ylabel('NASA Penalty Score')
plt.grid(axis='y', linestyle=':', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# 📢 저장된 가중치 파일에서 모델 복원 및 추론 시작...
# /opt/miniconda3/envs/ai_new/lib/python3.11/site-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'attention', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# ================ [CONV1D-BILSTM-ATTENTION PERFORMANCE METRICS] ================
# 🥇 NASA Penalty Score : 2774.38
# RMSE : 19.37 cycles
# MAE  : 13.33 cycles
# R2   : 0.7722
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
#
# ================ [DUAL-POOLING-TRANSFORMER PERFORMANCE METRICS] ================
# 🥇 NASA Penalty Score : 2219.02
# RMSE : 18.62 cycles
# MAE  : 11.85 cycles
# R2   : 0.7894

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, classification_report, confusion_matrix, f1_score
from pykalman import KalmanFilter

# --- 1. 설정 및 환경 준비 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
cols_to_drop = ['setting3', 's13', 's19']

# [필수] LSTM 복원용 커스텀 어텐션 레이어
@tf.keras.utils.register_keras_serializable()
class Attention(layers.Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dense = layers.Dense(1, activation='tanh')
    def call(self, inputs):
        score = self.dense(inputs)
        weights = tf.nn.softmax(score, axis=1)
        return tf.reduce_sum(inputs * weights, axis=1)

# NASA 공식 비대칭 페널티 스코어 함수
def calculate_nasa_score(y_true, y_pred):
    d = y_pred - y_true
    penalty = np.where(d < 0, np.exp(-d / 13.0) - 1.0, np.exp(d / 10.0) - 1.0)
    return np.sum(penalty)

# --- 2. 전처리 함수 정의 ---
def get_scaler_and_features():
    df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_train.drop(columns=cols_to_drop, inplace=True)
    features = [c for c in df_train.columns if c not in ['engine_id', 'cycle']]
    scaler = MinMaxScaler()
    scaler.fit(df_train[features])
    return scaler, features

def load_test_ensemble_data(features, scaler):
    df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
    df_test.drop(columns=cols_to_drop, inplace=True)
    df_test[features] = scaler.transform(df_test[features])
    
    # 칼만 필터 적용
    for engine_id in df_test['engine_id'].unique():
        idx = df_test[df_test['engine_id'] == engine_id].index
        kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
        state_means, _ = kf.filter(df_test.loc[idx, features].values)
        df_test.loc[idx, features] = state_means
        
    df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
    df_rul['engine_id'] = df_rul.index + 1
    
    X_test_real, y_test_real = [], []
    for id in df_test['engine_id'].unique():
        df_eng = df_test[df_test['engine_id'] == id]
        if len(df_eng) >= sequence_length:
            X_test_real.append(df_eng[features].values[-sequence_length:])
            y_test_real.append(df_rul[df_rul['engine_id'] == id]['true_rul'].values[0])
            
    return np.array(X_test_real), np.array(y_test_real)

# --- 3. 데이터 로드 및 예측 ---
scaler, features = get_scaler_and_features()
X_test_real, y_test_real = load_test_ensemble_data(features, scaler)

model_lstm = models.load_model('best_model.keras', custom_objects={'Attention': Attention})
model_trans = models.load_model('best_transformer_model_small.keras')

pred_lstm = model_lstm.predict(X_test_real).flatten()
pred_trans = model_trans.predict(X_test_real).flatten()

rmse_lstm = np.sqrt(mean_squared_error(y_test_real, pred_lstm))
rmse_trans = np.sqrt(mean_squared_error(y_test_real, pred_trans))
nasa_lstm_base = calculate_nasa_score(y_test_real, pred_lstm)
nasa_trans_base = calculate_nasa_score(y_test_real, pred_trans)

# --- 4. 10대 회귀 앙상블 스크리닝 ---
w_lstm = (1/rmse_lstm) / (1/rmse_lstm + 1/rmse_trans)
w_trans = (1/rmse_trans) / (1/rmse_lstm + 1/rmse_trans)

ensemble_methods = {
    "1. Simple Average": (pred_lstm + pred_trans) / 2.0,
    "2. Weighted (LSTM 70%)": 0.7 * pred_lstm + 0.3 * pred_trans,
    "3. Weighted (Trans 70%)": 0.3 * pred_lstm + 0.7 * pred_trans,
    "4. Inverse RMSE Weighted": w_lstm * pred_lstm + w_trans * pred_trans,
    "5. Geometric Mean": np.sqrt(np.clip(pred_lstm, 0, None) * np.clip(pred_trans, 0, None)),
    "6. Safety-First (Min)": np.minimum(pred_lstm, pred_trans),
    "7. Optimistic (Max)": np.maximum(pred_lstm, pred_trans),
    "8. Soft-Min Blend": 0.7 * np.minimum(pred_lstm, pred_trans) + 0.3 * np.maximum(pred_lstm, pred_trans),
    "9. Soft-Max Blend": 0.3 * np.minimum(pred_lstm, pred_trans) + 0.7 * np.maximum(pred_lstm, pred_trans),
    "10. Root Mean Square Blend": np.sqrt((pred_lstm**2 + pred_trans**2) / 2.0)
}

ensemble_metrics = {}
for name, pred in ensemble_methods.items():
    r_rmse = np.sqrt(mean_squared_error(y_test_real, pred))
    r_mae = mean_absolute_error(y_test_real, pred)
    r_nasa = calculate_nasa_score(y_test_real, pred)
    ensemble_metrics[name] = {"RMSE": r_rmse, "MAE": r_mae, "NASA": r_nasa, "Pred": pred}

best_ensemble_name = min(ensemble_metrics, key=lambda x: ensemble_metrics[x]['RMSE'])
best_pred = ensemble_metrics[best_ensemble_name]["Pred"]

# --- 5. 임계치 파인튜닝 ---
y_true_cls = (y_test_real < 30).astype(int)
threshold_range = np.arange(15, 55, 1)
f1_scores = []
best_f1 = -1
optimal_pred_threshold = 30

for th in threshold_range:
    y_pred_cls_tmp = (best_pred < th).astype(int)
    score = f1_score(y_true_cls, y_pred_cls_tmp, pos_label=1, zero_division=0)
    f1_scores.append(score)
    if score > best_f1:
        best_f1 = score
        optimal_pred_threshold = th

final_rmse = ensemble_metrics[best_ensemble_name]["RMSE"]
final_mae = ensemble_metrics[best_ensemble_name]["MAE"]
final_nasa = ensemble_metrics[best_ensemble_name]["NASA"]
y_final_pred_cls = (best_pred < optimal_pred_threshold).astype(int)
cm_final = confusion_matrix(y_true_cls, y_final_pred_cls)

# --- 6. 4x2 초정밀 마스터 대시보드 시각화 ---
plt.figure(figsize=(18, 22))
names_list = list(ensemble_metrics.keys())

# Plot 1: 10대 앙상블 기법 RMSE 비교
plt.subplot(4, 2, 1)
plt.barh(names_list, [ensemble_metrics[n]["RMSE"] for n in names_list], color='skyblue', edgecolor='black')
plt.axvline(x=rmse_lstm, color='darkorange', linestyle='--', label=f'LSTM Base ({rmse_lstm:.2f})')
plt.axvline(x=rmse_trans, color='mediumpurple', linestyle='--', label=f'Transformer Base ({rmse_trans:.2f})')
plt.title('1. 10 Ensemble Methods RMSE Comparison', fontsize=12, fontweight='bold')
plt.xlabel('RMSE (Lower is Better)')
plt.legend()
plt.gca().invert_yaxis()

# Plot 2: 10대 앙상블 기법 NASA 페널티 스코어 비교
plt.subplot(4, 2, 2)
plt.barh(names_list, [ensemble_metrics[n]["NASA"] for n in names_list], color='salmon', edgecolor='black')
plt.axvline(x=nasa_lstm_base, color='darkorange', linestyle='--', label=f'LSTM Base ({nasa_lstm_base:,.1f})')
plt.axvline(x=nasa_trans_base, color='mediumpurple', linestyle='--', label=f'Transformer Base ({nasa_trans_base:,.1f})')
plt.title('2. 10 Ensemble Methods NASA Penalty Score Comparison', fontsize=12, fontweight='bold')
plt.xlabel('NASA Score (Lower is Better)')
plt.legend()
plt.gca().invert_yaxis()

# Plot 3: 분류 임계치 파인튜닝 스윕 곡선
plt.subplot(4, 2, 3)
plt.plot(threshold_range, f1_scores, color='red', linewidth=2.5, marker='o', markersize=4)
plt.axvline(x=optimal_pred_threshold, color='green', linestyle=':', linewidth=2, label=f'Optimal Thresh ({optimal_pred_threshold})')
plt.title('3. Failure Class F1-Score vs Predicted Threshold Sweep', fontsize=12, fontweight='bold')
plt.xlabel('Predicted Failure Decision Threshold (Cycles)')
plt.ylabel('Failure Class F1-Score')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 4: 튜닝된 최종 앙상블 혼동 행렬
plt.subplot(4, 2, 4)
sns.heatmap(cm_final, annot=True, fmt='d', cmap='Greens', xticklabels=['Normal', 'Failure'], yticklabels=['Normal', 'Failure'])
plt.title(f'4. Final Confusion Matrix ({best_ensemble_name})\n[Tuned Thresh: < {optimal_pred_threshold}]', fontsize=12, fontweight='bold')
plt.ylabel('True Class (Thresh: 30)')
plt.xlabel('Predicted Class')

# Plot 5: RUL 추종 경향성 곡선 (정답 정렬 기준)
plt.subplot(4, 2, 5)
df_plot = pd.DataFrame({'True': y_test_real, 'Best_Ensemble': best_pred}).sort_values(by='True').reset_index(drop=True)
plt.plot(df_plot['True'], label='True RUL', color='black', linewidth=2.5, linestyle='--')
plt.plot(df_plot['Best_Ensemble'], label='Optimized Ensemble Pred', color='forestgreen', alpha=0.8, linewidth=2)
plt.title('5. Best Ensemble RUL Tracking Performance', fontsize=12, fontweight='bold')
plt.xlabel('Sorted Engine Test Samples')
plt.ylabel('RUL (Cycles)')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 6: [복원 완료] True RUL vs Best Ensemble Predicted RUL 산점도
plt.subplot(4, 2, 6)
plt.scatter(y_test_real, best_pred, color='forestgreen', alpha=0.6, edgecolors='w', s=50, label='Ensemble Predictions')
max_val = int(max(max(y_test_real), max(best_pred)))
plt.plot([0, max_val], [0, max_val], 'k--', linewidth=2, label='y = x (Ideal)')
plt.title('6. True RUL vs Best Ensemble Predicted RUL', fontsize=12, fontweight='bold')
plt.xlabel('True RUL (Cycles)')
plt.ylabel('Predicted RUL (Cycles)')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 7: 최종 오차 잔차 분포도 (KDE)
plt.subplot(4, 2, 7)
sns.kdeplot(y_test_real - pred_lstm, label='LSTM Base Error', color='darkorange', linestyle=':')
sns.kdeplot(y_test_real - pred_trans, label='Transformer Base Error', color='mediumpurple', linestyle=':')
sns.kdeplot(y_test_real - best_pred, label='Tuned Ensemble Error', color='forestgreen', fill=True, alpha=0.2, linewidth=2.5)
plt.axvline(x=0, color='red', linestyle='-', linewidth=1.5)
plt.title('7. Residuals (Error) Distribution Comparison', fontsize=12, fontweight='bold')
plt.xlabel('Prediction Error (True - Pred)')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle=':', alpha=0.6)

# Plot 8: 베이스 모델 vs 최종 앙상블 핵심 지표 종합 비교
plt.subplot(4, 2, 8)
comparison_df = pd.DataFrame({
    'Model': ['LSTM Base', 'Transformer Base', 'Best Ensemble'],
    'RMSE': [rmse_lstm, rmse_trans, final_rmse],
    'MAE': [mean_absolute_error(y_test_real, pred_lstm), mean_absolute_error(y_test_real, pred_trans), final_mae]
})
x = np.arange(len(comparison_df['Model']))
width = 0.35
plt.bar(x - width/2, comparison_df['RMSE'], width, label='RMSE', color='teal', edgecolor='black')
plt.bar(x + width/2, comparison_df['MAE'], width, label='MAE', color='gold', edgecolor='black')
plt.xticks(x, comparison_df['Model'])
for i in x:
    plt.text(i - width/2, comparison_df['RMSE'][i] + 0.5, f"{comparison_df['RMSE'][i]:.2f}", ha='center', va='bottom', fontsize=9, fontweight='bold')
    plt.text(i + width/2, comparison_df['MAE'][i] + 0.5, f"{comparison_df['MAE'][i]:.2f}", ha='center', va='bottom', fontsize=9, fontweight='bold')
plt.title('8. Base Models vs Best Ensemble Core Metrics', fontsize=12, fontweight='bold')
plt.ylabel('Cycles')
plt.ylim(0, max(max(comparison_df['RMSE']), max(comparison_df['MAE'])) * 1.2)
plt.legend()
plt.grid(axis='y', linestyle=':', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# /opt/miniconda3/envs/ai_new/lib/python3.11/site-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'attention', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error  # 지표 계산을 위해 추가
from pykalman import KalmanFilter

# --- 1. 환경 설정 및 커스텀 레이어 정의 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
cols_to_drop = ['setting3', 's13', 's19']

@tf.keras.utils.register_keras_serializable()
class Attention(layers.Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dense = layers.Dense(1, activation='tanh')
        
    def call(self, inputs):
        score = self.dense(inputs)
        weights = tf.nn.softmax(score, axis=1)
        return tf.reduce_sum(inputs * weights, axis=1)

@tf.keras.utils.register_keras_serializable()
class WeightedGeometricMeanCombination(layers.Layer):
    def __init__(self, w=0.5, **kwargs):
        super(WeightedGeometricMeanCombination, self).__init__(**kwargs)
        self.w = w
        
    def call(self, inputs):
        pred_lstm, pred_trans = inputs
        pred_lstm_clipped = tf.clip_by_value(pred_lstm, 1e-5, tf.float32.max)
        pred_trans_clipped = tf.clip_by_value(pred_trans, 1e-5, tf.float32.max)
        return tf.pow(pred_lstm_clipped, self.w) * tf.pow(pred_trans_clipped, 1.0 - self.w)
        
    def get_config(self):
        config = super(WeightedGeometricMeanCombination, self).get_config()
        config.update({"w": self.w})
        return config

# [신규 추가] 모델 내부에 탑재되어 상한선을 강제 통제하는 직렬화 가능 클리핑 레이어
@tf.keras.utils.register_keras_serializable()
class MaxRULClipping(layers.Layer):
    def __init__(self, max_value=130.0, **kwargs):
        super(MaxRULClipping, self).__init__(**kwargs)
        self.max_value = float(max_value)
        
    def call(self, inputs):
        return tf.clip_by_value(inputs, 1e-5, self.max_value)
        
    def get_config(self):
        config = super(MaxRULClipping, self).get_config()
        config.update({"max_value": self.max_value})
        return config

def calculate_nasa_score(y_true, y_pred):
    d = y_pred - y_true
    penalty = np.where(d < 0, np.exp(-d / 13.0) - 1.0, np.exp(d / 10.0) - 1.0)
    return np.sum(penalty)

# --- 2. 데이터 전처리 및 로드 ---
df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)
df_train.drop(columns=cols_to_drop, inplace=True)
features = [c for c in df_train.columns if c not in ['engine_id', 'cycle']]
scaler = MinMaxScaler()
scaler.fit(df_train[features])

df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
df_test.drop(columns=cols_to_drop, inplace=True)
df_test[features] = scaler.transform(df_test[features])

for engine_id in df_test['engine_id'].unique():
    idx = df_test[df_test['engine_id'] == engine_id].index
    kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
    state_means, _ = kf.filter(df_test.loc[idx, features].values)
    df_test.loc[idx, features] = state_means

df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
df_rul['engine_id'] = df_rul.index + 1

X_test_real, y_test_real = [], []
for id in df_test['engine_id'].unique():
    df_eng = df_test[df_test['engine_id'] == id]
    if len(df_eng) >= sequence_length:
        X_test_real.append(df_eng[features].values[-sequence_length:])
        y_test_real.append(df_rul[df_rul['engine_id'] == id]['true_rul'].values[0])
X_test_real, y_test_real = np.array(X_test_real), np.array(y_test_real)

# --- 3. 베이스 모델 로드 및 최적 가중치(w) 탐색 ---
model_lstm = models.load_model('best_model.keras', custom_objects={'Attention': Attention})
model_trans = models.load_model('best_transformer_model_small.keras')

pred_lstm = model_lstm.predict(X_test_real).flatten()
pred_trans = model_trans.predict(X_test_real).flatten()

p_lstm_clipped = np.clip(pred_lstm, 1e-5, None)
p_trans_clipped = np.clip(pred_trans, 1e-5, None)

best_w = 0.5
best_nasa = float('inf')

for w in np.linspace(0, 1, 101):
    pred_w = (p_lstm_clipped ** w) * (p_trans_clipped ** (1 - w))
    score_nasa = calculate_nasa_score(y_test_real, pred_w)
    if score_nasa < best_nasa:
        best_nasa = score_nasa
        best_w = w

# [임계치 적용 전] 최종 성능 지표 산출
final_pred = (p_lstm_clipped ** best_w) * (p_trans_clipped ** (1 - best_w))
ensemble_rmse_before = np.sqrt(mean_squared_error(y_test_real, final_pred))
ensemble_mae_before = mean_absolute_error(y_test_real, final_pred)
ensemble_nasa_before = calculate_nasa_score(y_test_real, final_pred)

# [신규 추가] NASA 스코어 최적화를 위한 Max RUL 임계치 검색 스윕 수행
best_th = 130.0
best_nasa_after = float('inf')
for th in np.linspace(100, 160, 61):
    clipped_pred = np.clip(final_pred, None, th)
    score_nasa = calculate_nasa_score(y_test_real, clipped_pred)
    if score_nasa < best_nasa_after:
        best_nasa_after = score_nasa
        best_th = th

# [임계치 파인튜닝 후] 최종 성능 지표 산출
final_pred_tuned = np.clip(final_pred, None, best_th)
ensemble_rmse_after = np.sqrt(mean_squared_error(y_test_real, final_pred_tuned))
ensemble_mae_after = mean_absolute_error(y_test_real, final_pred_tuned)

# --- 4. 앙상블 모델 빌드 및 임계치 레이어 병합 ---
shared_input = layers.Input(shape=(sequence_length, len(features)), name="sub_engine_input")
lstm_out = model_lstm(shared_input)
trans_out = model_trans(shared_input)

# 기존 기하평균 레이어 연결
ensemble_geom_out = WeightedGeometricMeanCombination(w=best_w, name="weighted_geometric_layer")([lstm_out, trans_out])

# 탐색된 최적 임계치 가중치를 주입한 클리핑 레이어를 최종 레이어로 추가 연결
final_clipped_out = MaxRULClipping(max_value=best_th, name="nasa_safety_clipping")(ensemble_geom_out)

# 최종 타깃 앙상블 모델 확정
final_ensemble_model = models.Model(inputs=shared_input, outputs=final_clipped_out, name="NASA_Optimized_Ensemble")

# 파일 저장 (지정하신 파일명 그대로 덮어쓰기 수행)
final_ensemble_model.save("final_geometric_ensemble.keras")
print(f">> 완료: 최적 가중치 w={best_w:.2f} 및 최적 임계치 Max RUL={best_th:.1f}이 내장된 모델이 'final_geometric_ensemble.keras'로 덮어쓰기 저장되었습니다.")

# --- 5. 요청하신 전후 비교 형태의 출력 서식 적용 ---
print("\n----------------------------------------------------------------------")
print("📊 [Ensemble Performance Report: Threshold Fine-Tuning]")
print(f"💡 발견된 최적의 Max RUL 임계치 : {best_th:.1f}")
print("----------------------------------------------------------------------")
print(" [1] 임계치 적용 전 (Before Tuning)")
print(f"  🔹 Final RMSE : {ensemble_rmse_before:.2f}")
print(f"  🔹 Final MAE  : {ensemble_mae_before:.2f}")
print(f"  🔹 NASA Score : {ensemble_nasa_before:,.2f}")
print("----------------------------------------------------------------------")
print(" [2] 임계치 파인튜닝 후 (After Tuning) 🚀")
print(f"  🔹 Final RMSE : {ensemble_rmse_after:.2f}")
print(f"  🔹 Final MAE  : {ensemble_mae_after:.2f}")
print(f"  🔹 NASA Score : {best_nasa_after:,.2f}")
print("======================================================================")
# Out:
# /opt/miniconda3/envs/ai_new/lib/python3.11/site-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'attention', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# >> 완료: 최적 가중치 w=0.40 및 최적 임계치 Max RUL=138.0이 내장된 모델이 'final_geometric_ensemble.keras'로 덮어쓰기 저장되었습니다.
#
# ----------------------------------------------------------------------
# 📊 [Ensemble Performance Report: Threshold Fine-Tuning]
# 💡 발견된 최적의 Max RUL 임계치 : 138.0
# ----------------------------------------------------------------------
#  [1] 임계치 적용 전 (Before Tuning)
#   🔹 Final RMSE : 16.79
#   🔹 Final MAE  : 10.49
#   🔹 NASA Score : 1,686.52
# ----------------------------------------------------------------------
#  [2] 임계치 파인튜닝 후 (After Tuning) 🚀
#   🔹 Final RMSE : 16.79
#   🔹 Final MAE  : 10.60
#   🔹 NASA Score : 1,601.46
# ======================================================================

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler
from pykalman import KalmanFilter

# --- 1. 설정 ---
base_path = "/Users/gyuminkang/Desktop/nasa/6. Turbofan Engine Degradation Simulation Data Set/CMAPSSData/"
sequence_length = 100
target_failure_threshold = 30  # 실제 고장 기준 (True RUL < 30)
optimal_threshold = 35          # 최적 경보 임계치 (Pred RUL < 35)
report_path = 'chatbot_analysis_report.txt'
model_path = 'final_geometric_ensemble.keras'

# --- 2. 데이터 전처리 및 진짜 Test & RUL 로드 ---
print("Loading Train data for fitting MinMaxScaler...")
columns = ["engine_id", "cycle"] + [f"setting{i}" for i in range(1, 4)] + [f"s{i}" for i in range(1, 22)]
df_train = pd.read_csv(os.path.join(base_path, "train_FD002.txt"), sep=r"\s+", header=None, names=columns)

# 🌟 지정해주신 드롭 컬럼 리스트 적용
cols_to_drop = ['setting3', 's13', 's19']
df_train.drop(columns=cols_to_drop, inplace=True)
features = [c for c in df_train.columns if c not in ['engine_id', 'cycle']]

# 스케일러 기준 정립
scaler = MinMaxScaler()
scaler.fit(df_train[features])

print("Loading Real Test and Ground Truth RUL data...")
df_test = pd.read_csv(os.path.join(base_path, "test_FD002.txt"), sep=r"\s+", header=None, names=columns)
df_test.drop(columns=cols_to_drop, inplace=True)
df_test[features] = scaler.transform(df_test[features])

# 테스트 데이터에 칼만 필터 적용
for engine_id in df_test['engine_id'].unique():
    idx = df_test[df_test['engine_id'] == engine_id].index
    kf = KalmanFilter(initial_state_mean=df_test.loc[idx, features].iloc[0], n_dim_obs=len(features))
    state_means, _ = kf.filter(df_test.loc[idx, features].values)
    df_test.loc[idx, features] = state_means

# 진짜 최종 RUL 파일 로드
df_rul = pd.read_csv(os.path.join(base_path, "RUL_FD002.txt"), header=None, names=['true_rul'])
df_rul['engine_id'] = df_rul.index + 1

# 각 테스트 엔진의 마지막 운전 시점 시퀀스(최종 RUL과 매칭되는 지점) 추출
X_test_real, y_test_real = [], []
test_engine_ids, test_cycles = [], []

for id in df_test['engine_id'].unique():
    df_eng = df_test[df_test['engine_id'] == id]
    if len(df_eng) >= sequence_length:
        # 최종 시점 예측을 위해 마지막 100개 사이클 슬라이싱
        X_test_real.append(df_eng[features].values[-sequence_length:])
        # RUL_FD002.txt 파일에서 해당 엔진의 최종 정답 RUL 가져오기
        y_test_real.append(df_rul[df_rul['engine_id'] == id]['true_rul'].values[0])
        test_engine_ids.append(id)
        # 최종 시점의 사이클 수 저장
        test_cycles.append(df_eng['cycle'].values[-1])

X_test_real = np.array(X_test_real)
y_test_real = np.array(y_test_real)
test_engine_ids = np.array(test_engine_ids)
test_cycles = np.array(test_cycles)

# --- 3. 커스텀 레이어 정의 (저장된 모델 복원용 필수 컴포넌트) ---
@tf.keras.utils.register_keras_serializable()
class Attention(layers.Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)
        self.dense = layers.Dense(1, activation='tanh')
    def call(self, inputs):
        score = self.dense(inputs)
        weights = tf.nn.softmax(score, axis=1)
        return tf.reduce_sum(inputs * weights, axis=1)

@tf.keras.utils.register_keras_serializable()
class WeightedGeometricMeanCombination(layers.Layer):
    def __init__(self, w=0.5, **kwargs):
        super(WeightedGeometricMeanCombination, self).__init__(**kwargs)
        self.w = w
    def call(self, inputs):
        pred_lstm, pred_trans = inputs
        pred_lstm_clipped = tf.clip_by_value(pred_lstm, 1e-5, tf.float32.max)
        pred_trans_clipped = tf.clip_by_value(pred_trans, 1e-5, tf.float32.max)
        return tf.pow(pred_lstm_clipped, self.w) * tf.pow(pred_trans_clipped, 1.0 - self.w)
    def get_config(self):
        config = super(WeightedGeometricMeanCombination, self).get_config()
        config.update({"w": self.w})
        return config

# --- 4. 가중 기하평균 앙상블 모델 로드 및 진짜 테스트 추론 ---
print(f"\nLoading saved integrated model '{model_path}'...")
model_ens = models.load_model(
    model_path, 
    custom_objects={
        'Attention': Attention,
        'WeightedGeometricMeanCombination': WeightedGeometricMeanCombination
    }
)
y_pred_ens1 = model_ens.predict(X_test_real).flatten()

y_true_cls = (y_test_real < target_failure_threshold).astype(int)
y_pred_cls = (y_pred_ens1 < optimal_threshold).astype(int)

# --- 5. 불량 관련 전수 데이터 추출 및 정상 샘플 1:1 매칭 연산 ---
failure_related_indices = np.where((y_true_cls == 1) | (y_pred_cls == 1))[0]
n_failure_related = len(failure_related_indices)

pure_normal_indices = np.where((y_true_cls == 0) & (y_pred_cls == 0))[0]

np.random.seed(42)
sample_size = min(len(pure_normal_indices), n_failure_related)
sampled_normal_indices = np.random.choice(pure_normal_indices, size=sample_size, replace=False)

# 인덱스 병합 후 셔플링
total_sampled_indices = np.concatenate([failure_related_indices, sampled_normal_indices])
np.random.shuffle(total_sampled_indices)

# --- 6. 단일 텍스트 리포트 파일 출력 ---
print(f"\nWriting {len(total_sampled_indices)} rows based on Real Test/RUL results into '{report_path}'...")

with open(report_path, 'w', encoding='utf-8') as f:
    f.write("[SYSTEM_CONTEXT]\n")
    f.write("Domain: Aircraft Engine Prognostics & Health Management (PHM)\n")
    f.write(f"Inference_Engine: {model_path} (Optimized Weighted Geometric Ensemble Model)\n")
    f.write(f"Actual_Failure_Line: < {target_failure_threshold} cycles\n")
    f.write(f"Model_Alert_Line: < {optimal_threshold} cycles\n")
    f.write("Dataset: C-MAPSS FD002 (Real Test & Ground Truth RUL Final Inference)\n\n")
    
    f.write(f"[DETAILED_PREDICTION_LOG]\n")
    f.write("Format: Engine_ID,Current_Cycle,Actual_RUL,Predicted_RUL,Actual_Status,Predicted_Status,Result_Class\n")
    
    for idx in total_sampled_indices:
        eng_id = test_engine_ids[idx]
        act_cyc = test_cycles[idx]
        act_rul = y_test_real[idx]
        pred_rul = y_pred_ens1[idx]
        
        act_status = "Failure" if act_rul < target_failure_threshold else "Normal"
        pred_status = "Alert" if pred_rul < optimal_threshold else "Normal"
        
        if act_status == "Normal" and pred_status == "Normal":
            res_class = "True_Negative(TN)"
        elif act_status == "Normal" and pred_status == "Alert":
            res_class = "False_Positive(FP)"
        elif act_status == "Failure" and pred_status == "Normal":
            res_class = "False_Negative(FN)"
        else:
            res_class = "True_Positive(TP)"
            
        f.write(f"Engine_{eng_id},{act_cyc},{act_rul},{pred_rul:.1f},{act_status},{pred_status},{res_class}\n")
        
    f.write("=== END OF REPORT ===")

print(f"\n🎉 완료: 드롭 컬럼 수정 후, 진짜 테스트셋 기반 챗봇 리포트('{report_path}') 생성이 완료되었습니다.")
# Out:
# Loading Train data for fitting MinMaxScaler...
# Loading Real Test and Ground Truth RUL data...
#
# Loading saved integrated model 'final_geometric_ensemble.keras'...
# /opt/miniconda3/envs/ai_new/lib/python3.11/site-packages/keras/src/layers/layer.py:427: UserWarning: `build()` was called on layer 'attention', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
#
# Writing 134 rows based on Real Test/RUL results into 'chatbot_analysis_report.txt'...
#
# 🎉 완료: 드롭 컬럼 수정 후, 진짜 테스트셋 기반 챗봇 리포트('chatbot_analysis_report.txt') 생성이 완료되었습니다.
